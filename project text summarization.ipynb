# %%
import pandas as pd
import nltk
import re
from nltk import sent_tokenize,word_tokenize,PorterStemmer
from nltk.corpus import stopwords
stopWords = set(stopwords.words("english"))
ps = PorterStemmer()
import math

# %%
text=open("data.txt","r")

# %%
text1=str(text.read())

# %%
#text1

# %%
def frequency_table(text):
    words=word_tokenize(text)
    word_freq=dict()
    for x in words:
        x=ps.stem(x.lower())
        if (x not in stopWords) and (len(x)>2):
            if x not in word_freq.keys():
                word_freq[x]=1
            else:
                word_freq[x]+=1
    return word_freq

# %%
#test frequency_table
sent="Narendra Damodardas Modi is an Indian politician serving as the 14th and current prime minister of India since 2014.";

# %%
frequency_table(text1)
# Out:
# {'narendra': 3,
#  'damodarda': 2,
#  'modi': 60,
#  'indian': 6,
#  'politician': 1,
#  'serv': 1,
#  '14th': 1,
#  'current': 1,
#  'prime': 3,
#  'minist': 6,
#  'india': 6,
#  'sinc': 3,
#  '2014': 4,
#  'chief': 3,
#  'gujarat': 21,
#  '2001': 4,
#  'member': 6,
#  'parliament': 2,
#  'varanasi': 1,
#  'bharatiya': 2,
#  'janata': 1,
#  'parti': 9,
#  'bjp': 18,
#  'nation': 6,
#  'democrat': 2,
#  'allianc': 1,
#  'nda': 1,
#  'also': 5,
#  'rashtriya': 2,
#  'swayamsevak': 2,
#  'sangh': 4,
#  'rss': 17,
#  'hindu': 4,
#  'nationalist': 2,
#  'volunt': 1,
#  'organis': 7,
#  'first': 5,
#  'born': 5,
#  'independ': 1,
#  '1947': 1,
#  'second': 1,
#  'non-congress': 1,
#  'one': 1,
#  'win': 3,
#  'two': 3,
#  'consecut': 1,
#  'term': 2,
#  'atal': 2,
#  'bihari': 2,
#  'vajpaye': 2,
#  'outsid': 1,
#  'congress': 3,
#  'major': 3,
#  'lok': 4,
#  'sabha': 3,
#  'rais': 3,
#  'vadnagar': 5,
#  'small': 1,
#  'town': 1,
#  'northeastern': 1,
#  'complet': 2,
#  'secondari': 2,
#  'educ': 5,
#  'said': 3,
#  'help': 4,
#  'father': 2,
#  'sell': 2,
#  'tea': 3,
#  'local': 2,
#  'railway': 2,
#  'station': 2,
#  'introduc': 3,
#  'age': 2,
#  'eight': 2,
#  'left': 2,
#  'home': 2,
#  'soon': 3,
#  'marriag': 3,
#  'jashodaben': 3,
#  'chamanl': 1,
#  'publicli': 2,
#  'acknowledg': 1,
#  'mani': 4,
#  'decad': 2,
#  'later': 6,
#  'assert': 1,
#  'travel': 5,
#  'around': 1,
#  'year': 8,
#  'visit': 3,
#  'number': 1,
#  'religi': 1,
#  'centr': 1,
#  'upon': 1,
#  'return': 4,
#  '1971': 3,
#  'becam': 6,
#  'full-tim': 2,
#  'worker': 1,
#  'dure': 7,
#  'state': 6,
#  'emerg': 8,
#  'impos': 1,
#  'across': 3,
#  'countri': 2,
#  '1975': 2,
#  'went': 4,
#  'hide': 1,
#  'assign': 2,
#  '1985': 2,
#  'held': 1,
#  'sever': 2,
#  'posit': 2,
#  'within': 3,
#  'hierarchi': 1,
#  'rise': 1,
#  'rank': 1,
#  'gener': 5,
#  'secretari': 6,
#  'appoint': 2,
#  'due': 1,
#  'keshubhai': 2,
#  'patel': 2,
#  'fail': 2,
#  'health': 2,
#  'poor': 1,
#  'public': 2,
#  'imag': 2,
#  'follow': 4,
#  'earthquak': 1,
#  'bhuj': 1,
#  'elect': 14,
#  'legisl': 1,
#  'assembl': 3,
#  'administr': 5,
#  'consid': 2,
#  'complicit': 1,
#  '2002': 2,
#  'riot': 2,
#  'otherwis': 1,
#  'criticis': 2,
#  'handl': 1,
#  'suprem': 1,
#  'court-appoint': 1,
#  'special': 2,
#  'investig': 1,
#  'team': 1,
#  'found': 3,
#  'evid': 2,
#  'initi': 2,
#  'prosecut': 1,
#  'proceed': 1,
#  'person': 1,
#  'polici': 1,
#  'credit': 2,
#  'encourag': 1,
#  'econom': 1,
#  'growth': 1,
#  'receiv': 3,
#  'prais': 1,
#  'significantli': 1,
#  'improv': 2,
#  'poverti': 1,
#  'indic': 1,
#  'led': 4,
#  'gave': 1,
#  'lower': 1,
#  'hous': 2,
#  'time': 3,
#  'ani': 1,
#  'singl': 1,
#  '1984': 1,
#  'tri': 1,
#  'foreign': 1,
#  'direct': 1,
#  'invest': 1,
#  'economi': 1,
#  'reduc': 1,
#  'spend': 1,
#  'healthcar': 1,
#  'social': 2,
#  'welfar': 1,
#  'programm': 1,
#  'attempt': 1,
#  'effici': 1,
#  'bureaucraci': 1,
#  'centralis': 1,
#  'power': 2,
#  'abolish': 2,
#  'plan': 2,
#  'commiss': 1,
#  'began': 2,
#  'high-profil': 1,
#  'sanit': 1,
#  'campaign': 3,
#  'controversi': 2,
#  'demonetis': 1,
#  'high-denomin': 1,
#  'banknot': 1,
#  'weaken': 1,
#  'environment': 1,
#  'labour': 1,
#  'law': 1,
#  'tenur': 1,
#  'experienc': 1,
#  'backslid': 1,
#  'victori': 2,
#  '2019': 1,
#  'revok': 1,
#  'statu': 1,
#  'jammu': 1,
#  'kashmir': 1,
#  'citizenship': 1,
#  'amend': 1,
#  'act': 1,
#  'result': 2,
#  'widespread': 1,
#  'protest': 2,
#  'describ': 6,
#  'engin': 1,
#  'polit': 14,
#  'realign': 1,
#  'toward': 1,
#  'right-w': 1,
#  'remain': 4,
#  'figur': 2,
#  'domest': 1,
#  'intern': 1,
#  'belief': 1,
#  'alleg': 1,
#  'role': 3,
#  'cite': 2,
#  'exclusionari': 1,
#  'agenda': 1,
#  'earli': 5,
#  'life': 2,
#  'septemb': 1,
#  '1950': 1,
#  'gujarati': 2,
#  'famili': 3,
#  'grocer': 1,
#  'mehsana': 1,
#  'district': 1,
#  'bombay': 1,
#  'present-day': 1,
#  'third': 2,
#  'six': 1,
#  'children': 1,
#  'mulchand': 1,
#  'c.â€‰1915â€': 1,
#  '1989': 1,
#  'hiraben': 1,
#  'c.â€‰1920': 1,
#  'belong': 1,
#  'modh-ghanchi-t': 1,
#  'oil-press': 1,
#  'commun': 1,
#  'categoris': 1,
#  'backward': 2,
#  'class': 4,
#  'govern': 5,
#  'fals': 1,
#  'accus': 1,
#  'mayawati': 1,
#  'cast': 2,
#  'obc': 1,
#  'list': 1,
#  'tool': 1,
#  'child': 1,
#  'ran': 1,
#  'stall': 1,
#  'brother': 1,
#  'near': 2,
#  'terminu': 1,
#  'higher': 1,
#  '1967': 1,
#  'teacher': 2,
#  'averag': 1,
#  'student': 3,
#  'keen': 1,
#  'debat': 2,
#  'interest': 1,
#  'theatr': 1,
#  'gift': 1,
#  'rhetor': 1,
#  'note': 1,
#  'thi': 7,
#  'prefer': 1,
#  'play': 2,
#  'larger-than-lif': 1,
#  'charact': 1,
#  'theatric': 1,
#  'product': 1,
#  'influenc': 2,
#  'old': 1,
#  'attend': 1,
#  'shakha': 1,
#  'train': 2,
#  'session': 1,
#  'met': 3,
#  'lakshmanrao': 1,
#  'inamdar': 5,
#  'popularli': 1,
#  'known': 3,
#  'vakil': 1,
#  'saheb': 1,
#  'induct': 1,
#  'balswayamsevak': 1,
#  'junior': 1,
#  'cadet': 1,
#  'mentor': 2,
#  'vasant': 1,
#  'gajendragadkar': 1,
#  'nathal': 1,
#  'jaghda': 1,
#  'jana': 2,
#  'leader': 3,
#  'unit': 2,
#  '1980': 1,
#  'custom': 1,
#  'tradit': 1,
#  'arrang': 1,
#  'betroth': 1,
#  'girl': 1,
#  'chimanl': 1,
#  'lead': 2,
#  'afterward': 2,
#  'abandon': 1,
#  'bride': 1,
#  'coupl': 2,
#  'separ': 1,
#  'live': 2,
#  'neither': 1,
#  'marri': 3,
#  'unment': 1,
#  'pronounc': 1,
#  'april': 1,
#  'shortli': 3,
#  'befor': 4,
#  'swept': 1,
#  'affirm': 1,
#  'spous': 1,
#  'estrang': 1,
#  'spent': 1,
#  'ensu': 1,
#  'northern': 1,
#  'north-eastern': 1,
#  'though': 1,
#  'detail': 1,
#  'interview': 1,
#  'ashram': 2,
#  'swami': 1,
#  'vivekananda': 2,
#  'belur': 2,
#  'math': 2,
#  'kolkata': 1,
#  'advaita': 1,
#  'ashrama': 1,
#  'almora': 2,
#  'ramakrishna': 2,
#  'mission': 1,
#  'rajkot': 1,
#  'onli': 1,
#  'short': 3,
#  'lack': 1,
#  'requir': 1,
#  'colleg': 1,
#  'larg': 1,
#  'summer': 1,
#  '1968': 1,
#  'reach': 1,
#  'turn': 1,
#  'away': 1,
#  'wander': 1,
#  'calcutta': 1,
#  'west': 1,
#  'bengal': 1,
#  'assam': 1,
#  'stop': 2,
#  'siliguri': 1,
#  'guwahati': 1,
#  'reject': 1,
#  'back': 1,
#  'via': 1,
#  'delhi': 7,
#  'rajasthan': 1,
#  '1968â€': 1,
#  'sometim': 1,
#  'late': 1,
#  '1969': 1,
#  '1970': 1,
#  'brief': 2,
#  'leav': 1,
#  'ahmedabad': 5,
#  'uncl': 2,
#  'work': 6,
#  'latter': 1,
#  'canteen': 1,
#  'road': 1,
#  'transport': 1,
#  'corpor': 1,
#  'renew': 1,
#  'acquaint': 1,
#  'base': 1,
#  'hedgewar': 1,
#  'bhavan': 1,
#  'headquart': 1,
#  'citi': 1,
#  'activ': 3,
#  'adult': 1,
#  'join': 1,
#  'satyagraha': 1,
#  'enlist': 1,
#  'battlefield': 1,
#  'indira': 2,
#  'gandhi': 2,
#  'central': 2,
#  'disallow': 1,
#  'open': 2,
#  'support': 3,
#  'mukti': 1,
#  'bahini': 1,
#  'put': 2,
#  'tihar': 1,
#  'jail': 2,
#  'period': 3,
#  'indo-pakistani': 1,
#  'war': 2,
#  'pracharak': 2,
#  'took': 2,
#  'part': 2,
#  'non-viol': 1,
#  'new': 2,
#  'arrest': 2,
#  'reason': 2,
#  'would': 1,
#  'co-author': 1,
#  'biographi': 1,
#  'publish': 1,
#  '1978': 2,
#  'bachelor': 1,
#  'art': 2,
#  'degre': 2,
#  'scienc': 2,
#  'school': 2,
#  'learn': 2,
#  'univers': 2,
#  'graduat': 2,
#  'five': 1,
#  '1983': 1,
#  'master': 1,
#  'extern': 1,
#  'distanc': 1,
#  'career': 1,
#  'june': 1,
#  'declar': 1,
#  'last': 1,
#  '1977': 1,
#  'oppon': 1,
#  'opposit': 2,
#  'group': 1,
#  'ban': 2,
#  'sangharsh': 2,
#  'samiti': 1,
#  'committe': 3,
#  'co-ordin': 1,
#  'forc': 2,
#  'underground': 1,
#  'frequent': 1,
#  'disguis': 2,
#  'avoid': 1,
#  'involv': 2,
#  'print': 1,
#  'pamphlet': 1,
#  'oppos': 1,
#  'send': 1,
#  'demonstr': 1,
#  'creat': 1,
#  'network': 1,
#  'safe': 1,
#  'individu': 1,
#  'want': 1,
#  'fund': 1,
#  'refuge': 1,
#  'activist': 2,
#  'wrote': 1,
#  'book': 1,
#  'struggl': 1,
#  'event': 1,
#  'among': 1,
#  'peopl': 1,
#  'trade': 1,
#  'unionist': 1,
#  'socialist': 1,
#  'georg': 1,
#  'fernand': 1,
#  'well': 1,
#  'often': 1,
#  'move': 1,
#  'onc': 2,
#  'dress': 1,
#  'monk': 1,
#  'sikh': 1,
#  'sambhag': 1,
#  'region': 1,
#  'overse': 1,
#  'area': 1,
#  'surat': 1,
#  'vadodara': 1,
#  '1979': 1,
#  'research': 1,
#  'write': 1,
#  'version': 1,
#  'histori': 1,
#  '1987': 2,
#  'municip': 1,
#  'comfort': 1,
#  'biograph': 1,
#  'advani': 3,
#  'presid': 1,
#  '1986': 1,
#  'decid': 1,
#  'place': 1,
#  'import': 1,
#  'select': 2,
#  'rose': 1,
#  'name': 1,
#  '1990': 3,
#  'ram': 1,
#  'rath': 1,
#  'yatra': 2,
#  'murli': 1,
#  'manohar': 1,
#  'joshi': 1,
#  '1991â€': 1,
#  'ekta': 1,
#  'journey': 1,
#  'uniti': 1,
#  'howev': 1,
#  'break': 1,
#  '1992': 1,
#  'instead': 1,
#  'establish': 1,
#  'friction': 1,
#  'shankersinh': 2,
#  'vaghela': 3,
#  'decis': 1,
#  'elector': 2,
#  '1994': 1,
#  'partli': 1,
#  'insist': 1,
#  'strategi': 2,
#  '1995': 1,
#  'novemb': 1,
#  'transfer': 1,
#  'assum': 1,
#  'respons': 1,
#  'haryana': 1,
#  'himach': 1,
#  'pradesh': 1,
#  'promin': 1,
#  'defect': 1,
#  'inc': 1,
#  'lose': 1,
#  'parliamentari': 1,
#  'seat': 1,
#  '1998': 2,
#  'favour': 1,
#  'end': 1,
#  'faction': 1,
#  'divis': 1,
#  'key': 1,
#  'overal': 1,
#  'promot': 1,
#  'may': 1}

# %%
def frequency_matrix(sentences):
    frequency_matrix=dict()
    for sent in sent_tokenize(sentences):
        frequency_matrix[sent[:15]]=frequency_table(sent)
    return frequency_matrix

# %%
freq_matrix=frequency_matrix(text1)
freq_matrix
# Out:
# {'Narendra Damoda': {'narendra': 1,
#   'damodarda': 1,
#   'modi': 1,
#   'indian': 1,
#   'politician': 1,
#   'serv': 1,
#   '14th': 1,
#   'current': 1,
#   'prime': 1,
#   'minist': 1,
#   'india': 1,
#   'sinc': 1,
#   '2014': 1},
#  'He was the chie': {'chief': 1,
#   'minist': 1,
#   'gujarat': 1,
#   '2001': 1,
#   '2014': 1,
#   'member': 1,
#   'parliament': 1,
#   'varanasi': 1},
#  'Modi is a membe': {'modi': 1,
#   'member': 1,
#   'bharatiya': 1,
#   'janata': 1,
#   'parti': 1,
#   'bjp': 1,
#   'nation': 1,
#   'democrat': 1,
#   'allianc': 1,
#   'nda': 1},
#  'He is also a me': {'also': 1,
#   'member': 1,
#   'rashtriya': 1,
#   'swayamsevak': 1,
#   'sangh': 1,
#   'rss': 1,
#   'hindu': 1,
#   'nationalist': 1,
#   'volunt': 1,
#   'organis': 1},
#  'He is the first': {'first': 2,
#   'prime': 1,
#   'minist': 1,
#   'born': 1,
#   'india': 1,
#   'independ': 1,
#   '1947': 1,
#   'second': 1,
#   'non-congress': 1,
#   'one': 1,
#   'win': 2,
#   'two': 1,
#   'consecut': 1,
#   'term': 2,
#   'atal': 1,
#   'bihari': 1,
#   'vajpaye': 1,
#   'outsid': 1,
#   'congress': 1,
#   'major': 1,
#   'lok': 1,
#   'sabha': 1},
#  'Born and raised': {'born': 1,
#   'rais': 1,
#   'vadnagar': 1,
#   'small': 1,
#   'town': 1,
#   'northeastern': 1,
#   'gujarat': 1,
#   'modi': 1,
#   'complet': 1,
#   'secondari': 1,
#   'educ': 1,
#   'said': 1,
#   'help': 1,
#   'father': 1,
#   'sell': 1,
#   'tea': 1,
#   'local': 1,
#   'railway': 1,
#   'station': 1},
#  'He was introduc': {'introduc': 1, 'rss': 1, 'age': 1, 'eight': 1},
#  'Modi left home ': {'modi': 1,
#   'left': 1,
#   'home': 1,
#   'age': 1,
#   'soon': 1,
#   'marriag': 1,
#   'jashodaben': 1,
#   'chamanl': 1,
#   'publicli': 1,
#   'acknowledg': 1,
#   'mani': 1,
#   'decad': 1,
#   'later': 1},
#  'Modi has assert': {'modi': 1,
#   'assert': 1,
#   'travel': 1,
#   'around': 1,
#   'india': 1,
#   'two': 1,
#   'year': 1,
#   'visit': 1,
#   'number': 1,
#   'religi': 1,
#   'centr': 1},
#  'Upon his return': {'upon': 1,
#   'return': 1,
#   'gujarat': 1,
#   '1971': 1,
#   'becam': 1,
#   'full-tim': 1,
#   'worker': 1,
#   'rss': 1},
#  'During the stat': {'dure': 1,
#   'state': 1,
#   'emerg': 1,
#   'impos': 1,
#   'across': 1,
#   'countri': 1,
#   '1975': 1,
#   'modi': 1,
#   'went': 1,
#   'hide': 1},
#  'The RSS assigne': {'rss': 1,
#   'assign': 1,
#   'bjp': 1,
#   '1985': 1,
#   'held': 1,
#   'sever': 1,
#   'posit': 1,
#   'within': 1,
#   'parti': 1,
#   'hierarchi': 1,
#   '2001': 1,
#   'rise': 1,
#   'rank': 1,
#   'gener': 1,
#   'secretari': 1},
#  'Modi was appoin': {'modi': 1,
#   'appoint': 1,
#   'gener': 1,
#   'secretari': 1,
#   'gujarat': 2,
#   'lok': 1,
#   'sangharsh': 1,
#   'samiti': 1,
#   'rss': 1,
#   'committe': 1,
#   'co-ordin': 1,
#   'opposit': 1,
#   'emerg': 1},
#  'Modi was electe': {'modi': 1,
#   'elect': 1,
#   'legisl': 1,
#   'assembl': 1,
#   'soon': 1},
#  'His administrat': {'administr': 1,
#   'also': 1,
#   'introduc': 1,
#   'citizenship': 1,
#   'amend': 1,
#   'act': 1,
#   'result': 1,
#   'widespread': 1,
#   'protest': 1,
#   'across': 1,
#   'countri': 1},
#  'A Supreme Court': {'suprem': 1,
#   'court-appoint': 1,
#   'special': 1,
#   'investig': 1,
#   'team': 1,
#   'found': 1,
#   'evid': 1,
#   'initi': 1,
#   'prosecut': 1,
#   'proceed': 1,
#   'modi': 1,
#   'person': 1},
#  'His policies as': {'polici': 1,
#   'chief': 1,
#   'minist': 1,
#   'credit': 1,
#   'encourag': 1,
#   'econom': 1,
#   'growth': 1,
#   'receiv': 1,
#   'prais': 1},
#  'Modi led the BJ': {'modi': 1,
#   'led': 1,
#   'bjp': 1,
#   '2014': 1,
#   'gener': 1,
#   'elect': 1,
#   'gave': 1,
#   'parti': 2,
#   'major': 1,
#   'indian': 1,
#   'lower': 1,
#   'hous': 1,
#   'parliament': 1,
#   'lok': 1,
#   'sabha': 1,
#   'first': 1,
#   'time': 1,
#   'ani': 1,
#   'singl': 1,
#   'sinc': 1,
#   '1984': 1},
#  "Modi's administ": {'modi': 1,
#   'administr': 1,
#   'tri': 1,
#   'rais': 1,
#   'foreign': 1,
#   'direct': 1,
#   'invest': 1,
#   'indian': 1,
#   'economi': 1,
#   'reduc': 1,
#   'spend': 1,
#   'healthcar': 1,
#   'social': 1,
#   'welfar': 1,
#   'programm': 1},
#  'Modi has attemp': {'modi': 1,
#   'attempt': 1,
#   'improv': 1,
#   'effici': 1,
#   'bureaucraci': 1,
#   'centralis': 1,
#   'power': 1,
#   'abolish': 1,
#   'plan': 1,
#   'commiss': 1},
#  'He began a high': {'began': 1,
#   'high-profil': 1,
#   'sanit': 1,
#   'campaign': 1,
#   'initi': 1,
#   'controversi': 1,
#   'demonetis': 1,
#   'high-denomin': 1,
#   'banknot': 1,
#   'weaken': 1,
#   'abolish': 1,
#   'environment': 1,
#   'labour': 1,
#   'law': 1},
#  "Under Modi's te": {'modi': 1,
#   'tenur': 1,
#   'india': 1,
#   'experienc': 1,
#   'democrat': 1,
#   'backslid': 1},
#  'Following his p': {'follow': 1,
#   'parti': 1,
#   'victori': 1,
#   '2019': 1,
#   'gener': 1,
#   'elect': 1,
#   'administr': 1,
#   'revok': 1,
#   'special': 1,
#   'statu': 1,
#   'jammu': 1,
#   'kashmir': 1},
#  'Described as en': {'describ': 1,
#   'engin': 1,
#   'polit': 2,
#   'realign': 1,
#   'toward': 1,
#   'right-w': 1,
#   'modi': 1,
#   'remain': 1,
#   'figur': 1,
#   'controversi': 1,
#   'domest': 1,
#   'intern': 1,
#   'hindu': 1,
#   'nationalist': 1,
#   'belief': 1,
#   'alleg': 1,
#   'role': 1,
#   'dure': 1,
#   '2002': 1,
#   'gujarat': 1,
#   'riot': 1,
#   'cite': 1,
#   'evid': 1,
#   'exclusionari': 1,
#   'social': 1,
#   'agenda': 1},
#  'Early life and ': {'earli': 1,
#   'life': 1,
#   'educ': 1,
#   'narendra': 1,
#   'modi': 1,
#   'born': 1,
#   'septemb': 1,
#   '1950': 1,
#   'gujarati': 1,
#   'hindu': 1,
#   'famili': 1,
#   'grocer': 1,
#   'vadnagar': 1,
#   'mehsana': 1,
#   'district': 1,
#   'bombay': 1,
#   'state': 1,
#   'present-day': 1,
#   'gujarat': 1},
#  'He was the thir': {'third': 1,
#   'six': 1,
#   'children': 1,
#   'born': 2,
#   'damodarda': 1,
#   'mulchand': 1,
#   'modi': 2,
#   'c.â€‰1915â€': 1,
#   '1989': 1,
#   'hiraben': 1,
#   'c.â€‰1920': 1},
#  "Modi's family b": {'modi': 1,
#   'famili': 1,
#   'belong': 1,
#   'modh-ghanchi-t': 1,
#   'oil-press': 1,
#   'commun': 1,
#   'categoris': 1,
#   'backward': 1,
#   'class': 1,
#   'indian': 1,
#   'govern': 1},
#  'He was falsely ': {'fals': 1,
#   'accus': 1,
#   'mayawati': 1,
#   'cast': 1,
#   'backward': 1,
#   'class': 1,
#   'obc': 1,
#   'list': 1,
#   'polit': 1,
#   'tool': 1},
#  'As a child, Mod': {'child': 1,
#   'modi': 1,
#   'said': 2,
#   'help': 1,
#   'father': 1,
#   'sell': 1,
#   'tea': 2,
#   'vadnagar': 1,
#   'railway': 1,
#   'station': 1,
#   'later': 1,
#   'ran': 1,
#   'stall': 1,
#   'brother': 1,
#   'near': 1,
#   'terminu': 1},
#  'Modi completed ': {'modi': 1,
#   'complet': 1,
#   'higher': 1,
#   'secondari': 1,
#   'educ': 1,
#   'vadnagar': 1,
#   '1967': 1,
#   'teacher': 1,
#   'describ': 1,
#   'averag': 1,
#   'student': 1,
#   'keen': 1,
#   'debat': 1,
#   'interest': 1,
#   'theatr': 1},
#  'Modi had an ear': {'modi': 1,
#   'earli': 1,
#   'gift': 1,
#   'rhetor': 1,
#   'debat': 1,
#   'teacher': 1,
#   'student': 1,
#   'note': 1,
#   'thi': 1},
#  'Modi preferred ': {'modi': 1,
#   'prefer': 1,
#   'play': 1,
#   'larger-than-lif': 1,
#   'charact': 1,
#   'theatric': 1,
#   'product': 1,
#   'influenc': 1,
#   'polit': 1,
#   'imag': 1},
#  'When eight year': {'eight': 1,
#   'year': 1,
#   'old': 1,
#   'modi': 1,
#   'introduc': 1,
#   'rashtriya': 1,
#   'swayamsevak': 1,
#   'sangh': 1,
#   'rss': 1,
#   'began': 1,
#   'attend': 1,
#   'local': 1,
#   'shakha': 1,
#   'train': 1,
#   'session': 1},
#  'There, Modi met': {'modi': 1,
#   'met': 1,
#   'lakshmanrao': 1,
#   'inamdar': 1,
#   'popularli': 1,
#   'known': 1,
#   'vakil': 1,
#   'saheb': 1,
#   'induct': 1,
#   'balswayamsevak': 1,
#   'junior': 1,
#   'cadet': 1,
#   'rss': 1,
#   'becam': 1,
#   'polit': 1,
#   'mentor': 1},
#  'While Modi was ': {'modi': 1,
#   'train': 1,
#   'rss': 1,
#   'also': 1,
#   'met': 1,
#   'vasant': 1,
#   'gajendragadkar': 1,
#   'nathal': 1,
#   'jaghda': 1,
#   'bharatiya': 1,
#   'jana': 1,
#   'sangh': 1,
#   'leader': 1,
#   'found': 1,
#   'member': 1,
#   'bjp': 1,
#   'gujarat': 1,
#   'unit': 1,
#   '1980': 1},
#  'In a custom tra': {'custom': 1,
#   'tradit': 1,
#   'narendra': 1,
#   'modi': 2,
#   'cast': 1,
#   'famili': 1,
#   'arrang': 1,
#   'betroth': 1,
#   'girl': 1,
#   'jashodaben': 1,
#   'chimanl': 1,
#   'lead': 1,
#   'marriag': 1},
#  'Soon afterwards': {'soon': 1,
#   'afterward': 1,
#   'abandon': 1,
#   'bride': 1,
#   'left': 1,
#   'home': 1,
#   'coupl': 1,
#   'lead': 1,
#   'separ': 1,
#   'live': 1,
#   'neither': 1,
#   'marri': 1,
#   'marriag': 1,
#   'remain': 1,
#   'unment': 1,
#   'modi': 1,
#   'public': 1,
#   'pronounc': 1,
#   'mani': 1,
#   'decad': 1},
#  'In April 2014, ': {'april': 1,
#   '2014': 1,
#   'shortli': 1,
#   'befor': 1,
#   'nation': 1,
#   'elect': 1,
#   'swept': 1,
#   'power': 1,
#   'modi': 1,
#   'publicli': 1,
#   'affirm': 1,
#   'marri': 2,
#   'spous': 1,
#   'jashodaben': 1,
#   'coupl': 1,
#   'remain': 1,
#   'estrang': 1},
#  'Modi spent the ': {'modi': 1,
#   'spent': 1,
#   'ensu': 1,
#   'two': 1,
#   'year': 1,
#   'travel': 1,
#   'across': 1,
#   'northern': 1,
#   'north-eastern': 1,
#   'india': 1,
#   'though': 1,
#   'detail': 1,
#   'went': 1,
#   'emerg': 1},
#  'In interviews, ': {'interview': 1,
#   'modi': 1,
#   'describ': 1,
#   'visit': 1,
#   'hindu': 1,
#   'ashram': 1,
#   'found': 1,
#   'swami': 1,
#   'vivekananda': 1,
#   'belur': 1,
#   'math': 1,
#   'near': 1,
#   'kolkata': 1,
#   'follow': 1,
#   'advaita': 1,
#   'ashrama': 1,
#   'almora': 1,
#   'ramakrishna': 1,
#   'mission': 1,
#   'rajkot': 1},
#  'Modi remained o': {'modi': 1,
#   'remain': 1,
#   'onli': 1,
#   'short': 1,
#   'time': 1,
#   'sinc': 1,
#   'lack': 1,
#   'requir': 1,
#   'colleg': 1,
#   'educ': 1},
#  'Vivekananda has': {'vivekananda': 1,
#   'describ': 1,
#   'larg': 1,
#   'influenc': 1,
#   'modi': 1,
#   'life': 1},
#  'In the early su': {'earli': 1,
#   'summer': 1,
#   '1968': 1,
#   'modi': 2,
#   'reach': 1,
#   'belur': 1,
#   'math': 1,
#   'turn': 1,
#   'away': 1,
#   'wander': 1,
#   'calcutta': 1,
#   'west': 1,
#   'bengal': 1,
#   'assam': 1,
#   'stop': 1,
#   'siliguri': 1,
#   'guwahati': 1},
#  'Modi then went ': {'modi': 1,
#   'went': 1,
#   'ramakrishna': 1,
#   'ashram': 1,
#   'almora': 1,
#   'reject': 1,
#   'befor': 1,
#   'travel': 1,
#   'back': 1,
#   'gujarat': 1,
#   'via': 1,
#   'delhi': 1,
#   'rajasthan': 1,
#   '1968â€': 1},
#  'Sometime in lat': {'sometim': 1,
#   'late': 1,
#   '1969': 1,
#   'earli': 1,
#   '1970': 1,
#   'modi': 1,
#   'return': 1,
#   'vadnagar': 1,
#   'brief': 1,
#   'visit': 1,
#   'befor': 1,
#   'leav': 1,
#   'ahmedabad': 1},
#  'There, Modi liv': {'modi': 1,
#   'live': 1,
#   'uncl': 1,
#   'work': 1,
#   'latter': 1,
#   'canteen': 1,
#   'gujarat': 1,
#   'state': 1,
#   'road': 1,
#   'transport': 1,
#   'corpor': 1},
#  'In Ahmedabad, M': {'ahmedabad': 1,
#   'modi': 1,
#   'renew': 1,
#   'acquaint': 1,
#   'inamdar': 1,
#   'base': 1,
#   'hedgewar': 1,
#   'bhavan': 1,
#   'rss': 1,
#   'headquart': 1,
#   'citi': 1},
#  "Modi's first kn": {'modi': 1,
#   'first': 1,
#   'known': 1,
#   'polit': 1,
#   'activ': 1,
#   'adult': 1,
#   '1971': 1,
#   'join': 1,
#   'jana': 1,
#   'sangh': 1,
#   'satyagraha': 1,
#   'delhi': 1,
#   'led': 1,
#   'atal': 1,
#   'bihari': 1,
#   'vajpaye': 1,
#   'enlist': 1,
#   'battlefield': 1},
#  'But the Indira ': {'indira': 1,
#   'gandhi': 1,
#   'led': 1,
#   'central': 1,
#   'govern': 1,
#   'disallow': 1,
#   'open': 1,
#   'support': 1,
#   'mukti': 1,
#   'bahini': 1,
#   'modi': 1,
#   'put': 1,
#   'tihar': 1,
#   'jail': 1,
#   'short': 1,
#   'period': 1},
#  'After the Indo-': {'indo-pakistani': 1,
#   'war': 1,
#   '1971': 1,
#   'stop': 1,
#   'work': 2,
#   'uncl': 1,
#   'becam': 1,
#   'full-tim': 1,
#   'pracharak': 1,
#   'campaign': 1,
#   'rss': 1,
#   'inamdar': 1},
#  'Shortly before ': {'shortli': 1,
#   'befor': 1,
#   'war': 1,
#   'modi': 1,
#   'took': 1,
#   'part': 1,
#   'non-viol': 1,
#   'protest': 1,
#   'indian': 1,
#   'govern': 1,
#   'new': 1,
#   'delhi': 1,
#   'arrest': 1,
#   'thi': 1,
#   'cite': 1,
#   'reason': 1,
#   'inamdar': 1,
#   'elect': 1,
#   'mentor': 1},
#  'Many years late': {'mani': 1,
#   'year': 1,
#   'later': 1,
#   'modi': 1,
#   'would': 1,
#   'co-author': 1,
#   'biographi': 1,
#   'inamdar': 1,
#   'publish': 1,
#   '2001': 1},
#  'In 1978 Modi re': {'1978': 1,
#   'modi': 1,
#   'receiv': 1,
#   'bachelor': 1,
#   'art': 1,
#   'degre': 1,
#   'polit': 1,
#   'scienc': 1,
#   'school': 1,
#   'open': 1,
#   'learn': 1,
#   'univers': 1,
#   'delhi': 1,
#   'graduat': 1,
#   'third': 1,
#   'class': 1},
#  'Five years late': {'five': 1,
#   'year': 1,
#   'later': 1,
#   '1983': 1,
#   'receiv': 1,
#   'master': 1,
#   'art': 1,
#   'degre': 1,
#   'polit': 1,
#   'scienc': 1,
#   'gujarat': 1,
#   'univers': 1,
#   'graduat': 1,
#   'first': 1,
#   'class': 1,
#   'extern': 1,
#   'distanc': 1,
#   'learn': 1,
#   'student': 1},
#  'Early political': {'earli': 1,
#   'polit': 1,
#   'career': 1,
#   'june': 1,
#   '1975': 1,
#   'prime': 1,
#   'minist': 1,
#   'indira': 1,
#   'gandhi': 1,
#   'declar': 1,
#   'state': 1,
#   'emerg': 1,
#   'india': 1,
#   'last': 1,
#   '1977': 1},
#  'During this per': {'dure': 2,
#   'thi': 1,
#   'period': 1,
#   'modi': 1,
#   'wrote': 1,
#   'book': 1,
#   'gujarati': 1,
#   'sangharsh': 1,
#   'gujarat': 2,
#   'struggl': 1,
#   'describ': 1,
#   'event': 1,
#   'emerg': 1},
#  'Shortly afterwa': {'shortli': 1, 'afterward': 1, 'rss': 1, 'ban': 1},
#  'Modi was forced': {'modi': 1,
#   'forc': 1,
#   'underground': 1,
#   'gujarat': 1,
#   'frequent': 1,
#   'travel': 1,
#   'disguis': 1,
#   'avoid': 1,
#   'arrest': 1},
#  'He became invol': {'becam': 1,
#   'involv': 1,
#   'print': 1,
#   'pamphlet': 1,
#   'oppos': 1,
#   'govern': 1,
#   'send': 1,
#   'delhi': 1,
#   'organis': 1,
#   'demonstr': 1},
#  'Modi was also i': {'modi': 1,
#   'also': 1,
#   'involv': 1,
#   'creat': 1,
#   'network': 1,
#   'safe': 1,
#   'hous': 1,
#   'individu': 1,
#   'want': 1,
#   'govern': 1,
#   'rais': 1,
#   'fund': 1,
#   'polit': 1,
#   'refuge': 1,
#   'activist': 1},
#  'Among the peopl': {'among': 1,
#   'peopl': 1,
#   'met': 1,
#   'thi': 1,
#   'role': 1,
#   'trade': 1,
#   'unionist': 1,
#   'socialist': 1,
#   'activist': 1,
#   'georg': 1,
#   'fernand': 1,
#   'well': 1,
#   'sever': 1,
#   'nation': 1,
#   'polit': 1,
#   'figur': 1},
#  'In his travels ': {'travel': 1,
#   'dure': 1,
#   'emerg': 1,
#   'modi': 1,
#   'often': 1,
#   'forc': 1,
#   'move': 1,
#   'disguis': 1,
#   'onc': 2,
#   'dress': 1,
#   'monk': 1,
#   'sikh': 1},
#  'Modi became an ': {'modi': 1,
#   'becam': 1,
#   'rss': 4,
#   'sambhag': 1,
#   'pracharak': 1,
#   'region': 1,
#   'organis': 1,
#   '1978': 1,
#   'overse': 1,
#   'activ': 1,
#   'area': 1,
#   'surat': 1,
#   'vadodara': 1,
#   '1979': 1,
#   'went': 1,
#   'work': 2,
#   'delhi': 1,
#   'put': 1,
#   'research': 1,
#   'write': 1,
#   'version': 1,
#   'histori': 1,
#   'emerg': 1},
#  'He returned to ': {'return': 1,
#   'gujarat': 1,
#   'short': 1,
#   'later': 1,
#   'assign': 1,
#   'rss': 1,
#   'bjp': 1,
#   '1985': 1},
#  'In 1987 Modi he': {'1987': 1,
#   'modi': 2,
#   'help': 1,
#   'organis': 1,
#   'bjp': 2,
#   'campaign': 1,
#   'ahmedabad': 1,
#   'municip': 1,
#   'elect': 1,
#   'comfort': 1,
#   'plan': 1,
#   'describ': 1,
#   'reason': 1,
#   'result': 1,
#   'biograph': 1},
#  'After L. K. Adv': {'advani': 1,
#   'becam': 1,
#   'presid': 1,
#   'bjp': 3,
#   '1986': 1,
#   'rss': 1,
#   'decid': 1,
#   'place': 1,
#   'member': 1,
#   'import': 1,
#   'posit': 1,
#   'within': 1,
#   'modi': 2,
#   'work': 1,
#   'dure': 1,
#   'ahmedabad': 1,
#   'elect': 2,
#   'led': 1,
#   'select': 1,
#   'thi': 1,
#   'role': 1,
#   'organis': 1,
#   'secretari': 1,
#   'gujarat': 1,
#   'unit': 1,
#   'later': 1,
#   '1987': 1},
#  'Modi rose withi': {'modi': 1,
#   'rose': 1,
#   'within': 1,
#   'parti': 1,
#   'name': 1,
#   'member': 1,
#   'bjp': 1,
#   'nation': 1,
#   'elect': 1,
#   'committe': 1,
#   '1990': 3,
#   'help': 1,
#   'organis': 1,
#   'advani': 1,
#   'ram': 1,
#   'rath': 1,
#   'yatra': 2,
#   'murli': 1,
#   'manohar': 1,
#   'joshi': 1,
#   '1991â€': 1,
#   'ekta': 1,
#   'journey': 1,
#   'uniti': 1},
#  'However, he too': {'howev': 1,
#   'took': 1,
#   'brief': 1,
#   'break': 1,
#   'polit': 1,
#   '1992': 1,
#   'instead': 1,
#   'establish': 1,
#   'school': 1,
#   'ahmedabad': 1,
#   'friction': 1,
#   'shankersinh': 1,
#   'vaghela': 1,
#   'bjp': 1,
#   'gujarat': 1,
#   'time': 1,
#   'also': 1,
#   'play': 1,
#   'part': 1,
#   'thi': 1,
#   'decis': 1},
#  'Modi returned t': {'modi': 2,
#   'return': 1,
#   'elector': 2,
#   'polit': 1,
#   '1994': 1,
#   'partli': 1,
#   'insist': 1,
#   'advani': 1,
#   'parti': 1,
#   'secretari': 1,
#   'strategi': 1,
#   'consid': 1,
#   'central': 1,
#   'bjp': 1,
#   'victori': 1,
#   '1995': 1,
#   'state': 1,
#   'assembl': 1,
#   'elect': 1},
#  'In November of ': {'novemb': 1,
#   'year': 1,
#   'modi': 1,
#   'elect': 1,
#   'bjp': 1,
#   'nation': 1,
#   'secretari': 1,
#   'transfer': 1,
#   'new': 1,
#   'delhi': 1,
#   'assum': 1,
#   'respons': 1,
#   'parti': 1,
#   'activ': 1,
#   'haryana': 1,
#   'himach': 1,
#   'pradesh': 1},
#  'The following y': {'follow': 1,
#   'year': 1,
#   'shankersinh': 1,
#   'vaghela': 1,
#   'promin': 1,
#   'bjp': 1,
#   'leader': 1,
#   'gujarat': 1,
#   'defect': 1,
#   'indian': 1,
#   'nation': 1,
#   'congress': 2,
#   'inc': 1,
#   'lose': 1,
#   'parliamentari': 1,
#   'seat': 1,
#   'lok': 1,
#   'sabha': 1,
#   'elect': 1},
#  'Modi, on the se': {'modi': 1,
#   'select': 1,
#   'committe': 1,
#   '1998': 1,
#   'assembl': 1,
#   'elect': 1,
#   'gujarat': 1,
#   'favour': 1,
#   'support': 2,
#   'bjp': 1,
#   'leader': 1,
#   'keshubhai': 1,
#   'patel': 1,
#   'vaghela': 1,
#   'end': 1,
#   'faction': 1,
#   'divis': 1,
#   'parti': 1},
#  'His strategy wa': {'strategi': 1,
#   'credit': 1,
#   'key': 1,
#   'bjp': 2,
#   'win': 1,
#   'overal': 1,
#   'major': 1,
#   '1998': 1,
#   'elect': 1,
#   'modi': 1,
#   'promot': 1,
#   'gener': 1,
#   'secretari': 1,
#   'organis': 1,
#   'may': 1,
#   'year': 1}}

# %%
def tf_matrix(freq_matrix):
    tf_matrix={}
    for sent,freq_table in freq_matrix.items():
        tf_table={}
        ft_len=len(freq_table)
        for Dict in freq_table.keys():
            tf_table[Dict]=round(freq_table[Dict]/ft_len,2)
        tf_matrix[sent]=tf_table
    return tf_matrix

# %%
tf_matrix1=tf_matrix(freq_matrix)
tf_matrix1
# Out:
# {'Narendra Damoda': {'narendra': 0.08,
#   'damodarda': 0.08,
#   'modi': 0.08,
#   'indian': 0.08,
#   'politician': 0.08,
#   'serv': 0.08,
#   '14th': 0.08,
#   'current': 0.08,
#   'prime': 0.08,
#   'minist': 0.08,
#   'india': 0.08,
#   'sinc': 0.08,
#   '2014': 0.08},
#  'He was the chie': {'chief': 0.12,
#   'minist': 0.12,
#   'gujarat': 0.12,
#   '2001': 0.12,
#   '2014': 0.12,
#   'member': 0.12,
#   'parliament': 0.12,
#   'varanasi': 0.12},
#  'Modi is a membe': {'modi': 0.1,
#   'member': 0.1,
#   'bharatiya': 0.1,
#   'janata': 0.1,
#   'parti': 0.1,
#   'bjp': 0.1,
#   'nation': 0.1,
#   'democrat': 0.1,
#   'allianc': 0.1,
#   'nda': 0.1},
#  'He is also a me': {'also': 0.1,
#   'member': 0.1,
#   'rashtriya': 0.1,
#   'swayamsevak': 0.1,
#   'sangh': 0.1,
#   'rss': 0.1,
#   'hindu': 0.1,
#   'nationalist': 0.1,
#   'volunt': 0.1,
#   'organis': 0.1},
#  'He is the first': {'first': 0.09,
#   'prime': 0.05,
#   'minist': 0.05,
#   'born': 0.05,
#   'india': 0.05,
#   'independ': 0.05,
#   '1947': 0.05,
#   'second': 0.05,
#   'non-congress': 0.05,
#   'one': 0.05,
#   'win': 0.09,
#   'two': 0.05,
#   'consecut': 0.05,
#   'term': 0.09,
#   'atal': 0.05,
#   'bihari': 0.05,
#   'vajpaye': 0.05,
#   'outsid': 0.05,
#   'congress': 0.05,
#   'major': 0.05,
#   'lok': 0.05,
#   'sabha': 0.05},
#  'Born and raised': {'born': 0.05,
#   'rais': 0.05,
#   'vadnagar': 0.05,
#   'small': 0.05,
#   'town': 0.05,
#   'northeastern': 0.05,
#   'gujarat': 0.05,
#   'modi': 0.05,
#   'complet': 0.05,
#   'secondari': 0.05,
#   'educ': 0.05,
#   'said': 0.05,
#   'help': 0.05,
#   'father': 0.05,
#   'sell': 0.05,
#   'tea': 0.05,
#   'local': 0.05,
#   'railway': 0.05,
#   'station': 0.05},
#  'He was introduc': {'introduc': 0.25,
#   'rss': 0.25,
#   'age': 0.25,
#   'eight': 0.25},
#  'Modi left home ': {'modi': 0.08,
#   'left': 0.08,
#   'home': 0.08,
#   'age': 0.08,
#   'soon': 0.08,
#   'marriag': 0.08,
#   'jashodaben': 0.08,
#   'chamanl': 0.08,
#   'publicli': 0.08,
#   'acknowledg': 0.08,
#   'mani': 0.08,
#   'decad': 0.08,
#   'later': 0.08},
#  'Modi has assert': {'modi': 0.09,
#   'assert': 0.09,
#   'travel': 0.09,
#   'around': 0.09,
#   'india': 0.09,
#   'two': 0.09,
#   'year': 0.09,
#   'visit': 0.09,
#   'number': 0.09,
#   'religi': 0.09,
#   'centr': 0.09},
#  'Upon his return': {'upon': 0.12,
#   'return': 0.12,
#   'gujarat': 0.12,
#   '1971': 0.12,
#   'becam': 0.12,
#   'full-tim': 0.12,
#   'worker': 0.12,
#   'rss': 0.12},
#  'During the stat': {'dure': 0.1,
#   'state': 0.1,
#   'emerg': 0.1,
#   'impos': 0.1,
#   'across': 0.1,
#   'countri': 0.1,
#   '1975': 0.1,
#   'modi': 0.1,
#   'went': 0.1,
#   'hide': 0.1},
#  'The RSS assigne': {'rss': 0.07,
#   'assign': 0.07,
#   'bjp': 0.07,
#   '1985': 0.07,
#   'held': 0.07,
#   'sever': 0.07,
#   'posit': 0.07,
#   'within': 0.07,
#   'parti': 0.07,
#   'hierarchi': 0.07,
#   '2001': 0.07,
#   'rise': 0.07,
#   'rank': 0.07,
#   'gener': 0.07,
#   'secretari': 0.07},
#  'Modi was appoin': {'modi': 0.08,
#   'appoint': 0.08,
#   'gener': 0.08,
#   'secretari': 0.08,
#   'gujarat': 0.15,
#   'lok': 0.08,
#   'sangharsh': 0.08,
#   'samiti': 0.08,
#   'rss': 0.08,
#   'committe': 0.08,
#   'co-ordin': 0.08,
#   'opposit': 0.08,
#   'emerg': 0.08},
#  'Modi was electe': {'modi': 0.2,
#   'elect': 0.2,
#   'legisl': 0.2,
#   'assembl': 0.2,
#   'soon': 0.2},
#  'His administrat': {'administr': 0.09,
#   'also': 0.09,
#   'introduc': 0.09,
#   'citizenship': 0.09,
#   'amend': 0.09,
#   'act': 0.09,
#   'result': 0.09,
#   'widespread': 0.09,
#   'protest': 0.09,
#   'across': 0.09,
#   'countri': 0.09},
#  'A Supreme Court': {'suprem': 0.08,
#   'court-appoint': 0.08,
#   'special': 0.08,
#   'investig': 0.08,
#   'team': 0.08,
#   'found': 0.08,
#   'evid': 0.08,
#   'initi': 0.08,
#   'prosecut': 0.08,
#   'proceed': 0.08,
#   'modi': 0.08,
#   'person': 0.08},
#  'His policies as': {'polici': 0.11,
#   'chief': 0.11,
#   'minist': 0.11,
#   'credit': 0.11,
#   'encourag': 0.11,
#   'econom': 0.11,
#   'growth': 0.11,
#   'receiv': 0.11,
#   'prais': 0.11},
#  'Modi led the BJ': {'modi': 0.05,
#   'led': 0.05,
#   'bjp': 0.05,
#   '2014': 0.05,
#   'gener': 0.05,
#   'elect': 0.05,
#   'gave': 0.05,
#   'parti': 0.1,
#   'major': 0.05,
#   'indian': 0.05,
#   'lower': 0.05,
#   'hous': 0.05,
#   'parliament': 0.05,
#   'lok': 0.05,
#   'sabha': 0.05,
#   'first': 0.05,
#   'time': 0.05,
#   'ani': 0.05,
#   'singl': 0.05,
#   'sinc': 0.05,
#   '1984': 0.05},
#  "Modi's administ": {'modi': 0.07,
#   'administr': 0.07,
#   'tri': 0.07,
#   'rais': 0.07,
#   'foreign': 0.07,
#   'direct': 0.07,
#   'invest': 0.07,
#   'indian': 0.07,
#   'economi': 0.07,
#   'reduc': 0.07,
#   'spend': 0.07,
#   'healthcar': 0.07,
#   'social': 0.07,
#   'welfar': 0.07,
#   'programm': 0.07},
#  'Modi has attemp': {'modi': 0.1,
#   'attempt': 0.1,
#   'improv': 0.1,
#   'effici': 0.1,
#   'bureaucraci': 0.1,
#   'centralis': 0.1,
#   'power': 0.1,
#   'abolish': 0.1,
#   'plan': 0.1,
#   'commiss': 0.1},
#  'He began a high': {'began': 0.07,
#   'high-profil': 0.07,
#   'sanit': 0.07,
#   'campaign': 0.07,
#   'initi': 0.07,
#   'controversi': 0.07,
#   'demonetis': 0.07,
#   'high-denomin': 0.07,
#   'banknot': 0.07,
#   'weaken': 0.07,
#   'abolish': 0.07,
#   'environment': 0.07,
#   'labour': 0.07,
#   'law': 0.07},
#  "Under Modi's te": {'modi': 0.17,
#   'tenur': 0.17,
#   'india': 0.17,
#   'experienc': 0.17,
#   'democrat': 0.17,
#   'backslid': 0.17},
#  'Following his p': {'follow': 0.08,
#   'parti': 0.08,
#   'victori': 0.08,
#   '2019': 0.08,
#   'gener': 0.08,
#   'elect': 0.08,
#   'administr': 0.08,
#   'revok': 0.08,
#   'special': 0.08,
#   'statu': 0.08,
#   'jammu': 0.08,
#   'kashmir': 0.08},
#  'Described as en': {'describ': 0.04,
#   'engin': 0.04,
#   'polit': 0.08,
#   'realign': 0.04,
#   'toward': 0.04,
#   'right-w': 0.04,
#   'modi': 0.04,
#   'remain': 0.04,
#   'figur': 0.04,
#   'controversi': 0.04,
#   'domest': 0.04,
#   'intern': 0.04,
#   'hindu': 0.04,
#   'nationalist': 0.04,
#   'belief': 0.04,
#   'alleg': 0.04,
#   'role': 0.04,
#   'dure': 0.04,
#   '2002': 0.04,
#   'gujarat': 0.04,
#   'riot': 0.04,
#   'cite': 0.04,
#   'evid': 0.04,
#   'exclusionari': 0.04,
#   'social': 0.04,
#   'agenda': 0.04},
#  'Early life and ': {'earli': 0.05,
#   'life': 0.05,
#   'educ': 0.05,
#   'narendra': 0.05,
#   'modi': 0.05,
#   'born': 0.05,
#   'septemb': 0.05,
#   '1950': 0.05,
#   'gujarati': 0.05,
#   'hindu': 0.05,
#   'famili': 0.05,
#   'grocer': 0.05,
#   'vadnagar': 0.05,
#   'mehsana': 0.05,
#   'district': 0.05,
#   'bombay': 0.05,
#   'state': 0.05,
#   'present-day': 0.05,
#   'gujarat': 0.05},
#  'He was the thir': {'third': 0.09,
#   'six': 0.09,
#   'children': 0.09,
#   'born': 0.18,
#   'damodarda': 0.09,
#   'mulchand': 0.09,
#   'modi': 0.18,
#   'c.â€‰1915â€': 0.09,
#   '1989': 0.09,
#   'hiraben': 0.09,
#   'c.â€‰1920': 0.09},
#  "Modi's family b": {'modi': 0.09,
#   'famili': 0.09,
#   'belong': 0.09,
#   'modh-ghanchi-t': 0.09,
#   'oil-press': 0.09,
#   'commun': 0.09,
#   'categoris': 0.09,
#   'backward': 0.09,
#   'class': 0.09,
#   'indian': 0.09,
#   'govern': 0.09},
#  'He was falsely ': {'fals': 0.1,
#   'accus': 0.1,
#   'mayawati': 0.1,
#   'cast': 0.1,
#   'backward': 0.1,
#   'class': 0.1,
#   'obc': 0.1,
#   'list': 0.1,
#   'polit': 0.1,
#   'tool': 0.1},
#  'As a child, Mod': {'child': 0.06,
#   'modi': 0.06,
#   'said': 0.12,
#   'help': 0.06,
#   'father': 0.06,
#   'sell': 0.06,
#   'tea': 0.12,
#   'vadnagar': 0.06,
#   'railway': 0.06,
#   'station': 0.06,
#   'later': 0.06,
#   'ran': 0.06,
#   'stall': 0.06,
#   'brother': 0.06,
#   'near': 0.06,
#   'terminu': 0.06},
#  'Modi completed ': {'modi': 0.07,
#   'complet': 0.07,
#   'higher': 0.07,
#   'secondari': 0.07,
#   'educ': 0.07,
#   'vadnagar': 0.07,
#   '1967': 0.07,
#   'teacher': 0.07,
#   'describ': 0.07,
#   'averag': 0.07,
#   'student': 0.07,
#   'keen': 0.07,
#   'debat': 0.07,
#   'interest': 0.07,
#   'theatr': 0.07},
#  'Modi had an ear': {'modi': 0.11,
#   'earli': 0.11,
#   'gift': 0.11,
#   'rhetor': 0.11,
#   'debat': 0.11,
#   'teacher': 0.11,
#   'student': 0.11,
#   'note': 0.11,
#   'thi': 0.11},
#  'Modi preferred ': {'modi': 0.1,
#   'prefer': 0.1,
#   'play': 0.1,
#   'larger-than-lif': 0.1,
#   'charact': 0.1,
#   'theatric': 0.1,
#   'product': 0.1,
#   'influenc': 0.1,
#   'polit': 0.1,
#   'imag': 0.1},
#  'When eight year': {'eight': 0.07,
#   'year': 0.07,
#   'old': 0.07,
#   'modi': 0.07,
#   'introduc': 0.07,
#   'rashtriya': 0.07,
#   'swayamsevak': 0.07,
#   'sangh': 0.07,
#   'rss': 0.07,
#   'began': 0.07,
#   'attend': 0.07,
#   'local': 0.07,
#   'shakha': 0.07,
#   'train': 0.07,
#   'session': 0.07},
#  'There, Modi met': {'modi': 0.06,
#   'met': 0.06,
#   'lakshmanrao': 0.06,
#   'inamdar': 0.06,
#   'popularli': 0.06,
#   'known': 0.06,
#   'vakil': 0.06,
#   'saheb': 0.06,
#   'induct': 0.06,
#   'balswayamsevak': 0.06,
#   'junior': 0.06,
#   'cadet': 0.06,
#   'rss': 0.06,
#   'becam': 0.06,
#   'polit': 0.06,
#   'mentor': 0.06},
#  'While Modi was ': {'modi': 0.05,
#   'train': 0.05,
#   'rss': 0.05,
#   'also': 0.05,
#   'met': 0.05,
#   'vasant': 0.05,
#   'gajendragadkar': 0.05,
#   'nathal': 0.05,
#   'jaghda': 0.05,
#   'bharatiya': 0.05,
#   'jana': 0.05,
#   'sangh': 0.05,
#   'leader': 0.05,
#   'found': 0.05,
#   'member': 0.05,
#   'bjp': 0.05,
#   'gujarat': 0.05,
#   'unit': 0.05,
#   '1980': 0.05},
#  'In a custom tra': {'custom': 0.08,
#   'tradit': 0.08,
#   'narendra': 0.08,
#   'modi': 0.15,
#   'cast': 0.08,
#   'famili': 0.08,
#   'arrang': 0.08,
#   'betroth': 0.08,
#   'girl': 0.08,
#   'jashodaben': 0.08,
#   'chimanl': 0.08,
#   'lead': 0.08,
#   'marriag': 0.08},
#  'Soon afterwards': {'soon': 0.05,
#   'afterward': 0.05,
#   'abandon': 0.05,
#   'bride': 0.05,
#   'left': 0.05,
#   'home': 0.05,
#   'coupl': 0.05,
#   'lead': 0.05,
#   'separ': 0.05,
#   'live': 0.05,
#   'neither': 0.05,
#   'marri': 0.05,
#   'marriag': 0.05,
#   'remain': 0.05,
#   'unment': 0.05,
#   'modi': 0.05,
#   'public': 0.05,
#   'pronounc': 0.05,
#   'mani': 0.05,
#   'decad': 0.05},
#  'In April 2014, ': {'april': 0.06,
#   '2014': 0.06,
#   'shortli': 0.06,
#   'befor': 0.06,
#   'nation': 0.06,
#   'elect': 0.06,
#   'swept': 0.06,
#   'power': 0.06,
#   'modi': 0.06,
#   'publicli': 0.06,
#   'affirm': 0.06,
#   'marri': 0.12,
#   'spous': 0.06,
#   'jashodaben': 0.06,
#   'coupl': 0.06,
#   'remain': 0.06,
#   'estrang': 0.06},
#  'Modi spent the ': {'modi': 0.07,
#   'spent': 0.07,
#   'ensu': 0.07,
#   'two': 0.07,
#   'year': 0.07,
#   'travel': 0.07,
#   'across': 0.07,
#   'northern': 0.07,
#   'north-eastern': 0.07,
#   'india': 0.07,
#   'though': 0.07,
#   'detail': 0.07,
#   'went': 0.07,
#   'emerg': 0.07},
#  'In interviews, ': {'interview': 0.05,
#   'modi': 0.05,
#   'describ': 0.05,
#   'visit': 0.05,
#   'hindu': 0.05,
#   'ashram': 0.05,
#   'found': 0.05,
#   'swami': 0.05,
#   'vivekananda': 0.05,
#   'belur': 0.05,
#   'math': 0.05,
#   'near': 0.05,
#   'kolkata': 0.05,
#   'follow': 0.05,
#   'advaita': 0.05,
#   'ashrama': 0.05,
#   'almora': 0.05,
#   'ramakrishna': 0.05,
#   'mission': 0.05,
#   'rajkot': 0.05},
#  'Modi remained o': {'modi': 0.1,
#   'remain': 0.1,
#   'onli': 0.1,
#   'short': 0.1,
#   'time': 0.1,
#   'sinc': 0.1,
#   'lack': 0.1,
#   'requir': 0.1,
#   'colleg': 0.1,
#   'educ': 0.1},
#  'Vivekananda has': {'vivekananda': 0.17,
#   'describ': 0.17,
#   'larg': 0.17,
#   'influenc': 0.17,
#   'modi': 0.17,
#   'life': 0.17},
#  'In the early su': {'earli': 0.06,
#   'summer': 0.06,
#   '1968': 0.06,
#   'modi': 0.12,
#   'reach': 0.06,
#   'belur': 0.06,
#   'math': 0.06,
#   'turn': 0.06,
#   'away': 0.06,
#   'wander': 0.06,
#   'calcutta': 0.06,
#   'west': 0.06,
#   'bengal': 0.06,
#   'assam': 0.06,
#   'stop': 0.06,
#   'siliguri': 0.06,
#   'guwahati': 0.06},
#  'Modi then went ': {'modi': 0.07,
#   'went': 0.07,
#   'ramakrishna': 0.07,
#   'ashram': 0.07,
#   'almora': 0.07,
#   'reject': 0.07,
#   'befor': 0.07,
#   'travel': 0.07,
#   'back': 0.07,
#   'gujarat': 0.07,
#   'via': 0.07,
#   'delhi': 0.07,
#   'rajasthan': 0.07,
#   '1968â€': 0.07},
#  'Sometime in lat': {'sometim': 0.08,
#   'late': 0.08,
#   '1969': 0.08,
#   'earli': 0.08,
#   '1970': 0.08,
#   'modi': 0.08,
#   'return': 0.08,
#   'vadnagar': 0.08,
#   'brief': 0.08,
#   'visit': 0.08,
#   'befor': 0.08,
#   'leav': 0.08,
#   'ahmedabad': 0.08},
#  'There, Modi liv': {'modi': 0.09,
#   'live': 0.09,
#   'uncl': 0.09,
#   'work': 0.09,
#   'latter': 0.09,
#   'canteen': 0.09,
#   'gujarat': 0.09,
#   'state': 0.09,
#   'road': 0.09,
#   'transport': 0.09,
#   'corpor': 0.09},
#  'In Ahmedabad, M': {'ahmedabad': 0.09,
#   'modi': 0.09,
#   'renew': 0.09,
#   'acquaint': 0.09,
#   'inamdar': 0.09,
#   'base': 0.09,
#   'hedgewar': 0.09,
#   'bhavan': 0.09,
#   'rss': 0.09,
#   'headquart': 0.09,
#   'citi': 0.09},
#  "Modi's first kn": {'modi': 0.06,
#   'first': 0.06,
#   'known': 0.06,
#   'polit': 0.06,
#   'activ': 0.06,
#   'adult': 0.06,
#   '1971': 0.06,
#   'join': 0.06,
#   'jana': 0.06,
#   'sangh': 0.06,
#   'satyagraha': 0.06,
#   'delhi': 0.06,
#   'led': 0.06,
#   'atal': 0.06,
#   'bihari': 0.06,
#   'vajpaye': 0.06,
#   'enlist': 0.06,
#   'battlefield': 0.06},
#  'But the Indira ': {'indira': 0.06,
#   'gandhi': 0.06,
#   'led': 0.06,
#   'central': 0.06,
#   'govern': 0.06,
#   'disallow': 0.06,
#   'open': 0.06,
#   'support': 0.06,
#   'mukti': 0.06,
#   'bahini': 0.06,
#   'modi': 0.06,
#   'put': 0.06,
#   'tihar': 0.06,
#   'jail': 0.06,
#   'short': 0.06,
#   'period': 0.06},
#  'After the Indo-': {'indo-pakistani': 0.08,
#   'war': 0.08,
#   '1971': 0.08,
#   'stop': 0.08,
#   'work': 0.17,
#   'uncl': 0.08,
#   'becam': 0.08,
#   'full-tim': 0.08,
#   'pracharak': 0.08,
#   'campaign': 0.08,
#   'rss': 0.08,
#   'inamdar': 0.08},
#  'Shortly before ': {'shortli': 0.05,
#   'befor': 0.05,
#   'war': 0.05,
#   'modi': 0.05,
#   'took': 0.05,
#   'part': 0.05,
#   'non-viol': 0.05,
#   'protest': 0.05,
#   'indian': 0.05,
#   'govern': 0.05,
#   'new': 0.05,
#   'delhi': 0.05,
#   'arrest': 0.05,
#   'thi': 0.05,
#   'cite': 0.05,
#   'reason': 0.05,
#   'inamdar': 0.05,
#   'elect': 0.05,
#   'mentor': 0.05},
#  'Many years late': {'mani': 0.1,
#   'year': 0.1,
#   'later': 0.1,
#   'modi': 0.1,
#   'would': 0.1,
#   'co-author': 0.1,
#   'biographi': 0.1,
#   'inamdar': 0.1,
#   'publish': 0.1,
#   '2001': 0.1},
#  'In 1978 Modi re': {'1978': 0.06,
#   'modi': 0.06,
#   'receiv': 0.06,
#   'bachelor': 0.06,
#   'art': 0.06,
#   'degre': 0.06,
#   'polit': 0.06,
#   'scienc': 0.06,
#   'school': 0.06,
#   'open': 0.06,
#   'learn': 0.06,
#   'univers': 0.06,
#   'delhi': 0.06,
#   'graduat': 0.06,
#   'third': 0.06,
#   'class': 0.06},
#  'Five years late': {'five': 0.05,
#   'year': 0.05,
#   'later': 0.05,
#   '1983': 0.05,
#   'receiv': 0.05,
#   'master': 0.05,
#   'art': 0.05,
#   'degre': 0.05,
#   'polit': 0.05,
#   'scienc': 0.05,
#   'gujarat': 0.05,
#   'univers': 0.05,
#   'graduat': 0.05,
#   'first': 0.05,
#   'class': 0.05,
#   'extern': 0.05,
#   'distanc': 0.05,
#   'learn': 0.05,
#   'student': 0.05},
#  'Early political': {'earli': 0.07,
#   'polit': 0.07,
#   'career': 0.07,
#   'june': 0.07,
#   '1975': 0.07,
#   'prime': 0.07,
#   'minist': 0.07,
#   'indira': 0.07,
#   'gandhi': 0.07,
#   'declar': 0.07,
#   'state': 0.07,
#   'emerg': 0.07,
#   'india': 0.07,
#   'last': 0.07,
#   '1977': 0.07},
#  'During this per': {'dure': 0.15,
#   'thi': 0.08,
#   'period': 0.08,
#   'modi': 0.08,
#   'wrote': 0.08,
#   'book': 0.08,
#   'gujarati': 0.08,
#   'sangharsh': 0.08,
#   'gujarat': 0.15,
#   'struggl': 0.08,
#   'describ': 0.08,
#   'event': 0.08,
#   'emerg': 0.08},
#  'Shortly afterwa': {'shortli': 0.25,
#   'afterward': 0.25,
#   'rss': 0.25,
#   'ban': 0.25},
#  'Modi was forced': {'modi': 0.11,
#   'forc': 0.11,
#   'underground': 0.11,
#   'gujarat': 0.11,
#   'frequent': 0.11,
#   'travel': 0.11,
#   'disguis': 0.11,
#   'avoid': 0.11,
#   'arrest': 0.11},
#  'He became invol': {'becam': 0.1,
#   'involv': 0.1,
#   'print': 0.1,
#   'pamphlet': 0.1,
#   'oppos': 0.1,
#   'govern': 0.1,
#   'send': 0.1,
#   'delhi': 0.1,
#   'organis': 0.1,
#   'demonstr': 0.1},
#  'Modi was also i': {'modi': 0.07,
#   'also': 0.07,
#   'involv': 0.07,
#   'creat': 0.07,
#   'network': 0.07,
#   'safe': 0.07,
#   'hous': 0.07,
#   'individu': 0.07,
#   'want': 0.07,
#   'govern': 0.07,
#   'rais': 0.07,
#   'fund': 0.07,
#   'polit': 0.07,
#   'refuge': 0.07,
#   'activist': 0.07},
#  'Among the peopl': {'among': 0.06,
#   'peopl': 0.06,
#   'met': 0.06,
#   'thi': 0.06,
#   'role': 0.06,
#   'trade': 0.06,
#   'unionist': 0.06,
#   'socialist': 0.06,
#   'activist': 0.06,
#   'georg': 0.06,
#   'fernand': 0.06,
#   'well': 0.06,
#   'sever': 0.06,
#   'nation': 0.06,
#   'polit': 0.06,
#   'figur': 0.06},
#  'In his travels ': {'travel': 0.08,
#   'dure': 0.08,
#   'emerg': 0.08,
#   'modi': 0.08,
#   'often': 0.08,
#   'forc': 0.08,
#   'move': 0.08,
#   'disguis': 0.08,
#   'onc': 0.17,
#   'dress': 0.08,
#   'monk': 0.08,
#   'sikh': 0.08},
#  'Modi became an ': {'modi': 0.04,
#   'becam': 0.04,
#   'rss': 0.17,
#   'sambhag': 0.04,
#   'pracharak': 0.04,
#   'region': 0.04,
#   'organis': 0.04,
#   '1978': 0.04,
#   'overse': 0.04,
#   'activ': 0.04,
#   'area': 0.04,
#   'surat': 0.04,
#   'vadodara': 0.04,
#   '1979': 0.04,
#   'went': 0.04,
#   'work': 0.09,
#   'delhi': 0.04,
#   'put': 0.04,
#   'research': 0.04,
#   'write': 0.04,
#   'version': 0.04,
#   'histori': 0.04,
#   'emerg': 0.04},
#  'He returned to ': {'return': 0.12,
#   'gujarat': 0.12,
#   'short': 0.12,
#   'later': 0.12,
#   'assign': 0.12,
#   'rss': 0.12,
#   'bjp': 0.12,
#   '1985': 0.12},
#  'In 1987 Modi he': {'1987': 0.07,
#   'modi': 0.13,
#   'help': 0.07,
#   'organis': 0.07,
#   'bjp': 0.13,
#   'campaign': 0.07,
#   'ahmedabad': 0.07,
#   'municip': 0.07,
#   'elect': 0.07,
#   'comfort': 0.07,
#   'plan': 0.07,
#   'describ': 0.07,
#   'reason': 0.07,
#   'result': 0.07,
#   'biograph': 0.07},
#  'After L. K. Adv': {'advani': 0.04,
#   'becam': 0.04,
#   'presid': 0.04,
#   'bjp': 0.11,
#   '1986': 0.04,
#   'rss': 0.04,
#   'decid': 0.04,
#   'place': 0.04,
#   'member': 0.04,
#   'import': 0.04,
#   'posit': 0.04,
#   'within': 0.04,
#   'modi': 0.07,
#   'work': 0.04,
#   'dure': 0.04,
#   'ahmedabad': 0.04,
#   'elect': 0.07,
#   'led': 0.04,
#   'select': 0.04,
#   'thi': 0.04,
#   'role': 0.04,
#   'organis': 0.04,
#   'secretari': 0.04,
#   'gujarat': 0.04,
#   'unit': 0.04,
#   'later': 0.04,
#   '1987': 0.04},
#  'Modi rose withi': {'modi': 0.04,
#   'rose': 0.04,
#   'within': 0.04,
#   'parti': 0.04,
#   'name': 0.04,
#   'member': 0.04,
#   'bjp': 0.04,
#   'nation': 0.04,
#   'elect': 0.04,
#   'committe': 0.04,
#   '1990': 0.12,
#   'help': 0.04,
#   'organis': 0.04,
#   'advani': 0.04,
#   'ram': 0.04,
#   'rath': 0.04,
#   'yatra': 0.08,
#   'murli': 0.04,
#   'manohar': 0.04,
#   'joshi': 0.04,
#   '1991â€': 0.04,
#   'ekta': 0.04,
#   'journey': 0.04,
#   'uniti': 0.04},
#  'However, he too': {'howev': 0.05,
#   'took': 0.05,
#   'brief': 0.05,
#   'break': 0.05,
#   'polit': 0.05,
#   '1992': 0.05,
#   'instead': 0.05,
#   'establish': 0.05,
#   'school': 0.05,
#   'ahmedabad': 0.05,
#   'friction': 0.05,
#   'shankersinh': 0.05,
#   'vaghela': 0.05,
#   'bjp': 0.05,
#   'gujarat': 0.05,
#   'time': 0.05,
#   'also': 0.05,
#   'play': 0.05,
#   'part': 0.05,
#   'thi': 0.05,
#   'decis': 0.05},
#  'Modi returned t': {'modi': 0.11,
#   'return': 0.05,
#   'elector': 0.11,
#   'polit': 0.05,
#   '1994': 0.05,
#   'partli': 0.05,
#   'insist': 0.05,
#   'advani': 0.05,
#   'parti': 0.05,
#   'secretari': 0.05,
#   'strategi': 0.05,
#   'consid': 0.05,
#   'central': 0.05,
#   'bjp': 0.05,
#   'victori': 0.05,
#   '1995': 0.05,
#   'state': 0.05,
#   'assembl': 0.05,
#   'elect': 0.05},
#  'In November of ': {'novemb': 0.06,
#   'year': 0.06,
#   'modi': 0.06,
#   'elect': 0.06,
#   'bjp': 0.06,
#   'nation': 0.06,
#   'secretari': 0.06,
#   'transfer': 0.06,
#   'new': 0.06,
#   'delhi': 0.06,
#   'assum': 0.06,
#   'respons': 0.06,
#   'parti': 0.06,
#   'activ': 0.06,
#   'haryana': 0.06,
#   'himach': 0.06,
#   'pradesh': 0.06},
#  'The following y': {'follow': 0.05,
#   'year': 0.05,
#   'shankersinh': 0.05,
#   'vaghela': 0.05,
#   'promin': 0.05,
#   'bjp': 0.05,
#   'leader': 0.05,
#   'gujarat': 0.05,
#   'defect': 0.05,
#   'indian': 0.05,
#   'nation': 0.05,
#   'congress': 0.11,
#   'inc': 0.05,
#   'lose': 0.05,
#   'parliamentari': 0.05,
#   'seat': 0.05,
#   'lok': 0.05,
#   'sabha': 0.05,
#   'elect': 0.05},
#  'Modi, on the se': {'modi': 0.06,
#   'select': 0.06,
#   'committe': 0.06,
#   '1998': 0.06,
#   'assembl': 0.06,
#   'elect': 0.06,
#   'gujarat': 0.06,
#   'favour': 0.06,
#   'support': 0.11,
#   'bjp': 0.06,
#   'leader': 0.06,
#   'keshubhai': 0.06,
#   'patel': 0.06,
#   'vaghela': 0.06,
#   'end': 0.06,
#   'faction': 0.06,
#   'divis': 0.06,
#   'parti': 0.06},
#  'His strategy wa': {'strategi': 0.06,
#   'credit': 0.06,
#   'key': 0.06,
#   'bjp': 0.12,
#   'win': 0.06,
#   'overal': 0.06,
#   'major': 0.06,
#   '1998': 0.06,
#   'elect': 0.06,
#   'modi': 0.06,
#   'promot': 0.06,
#   'gener': 0.06,
#   'secretari': 0.06,
#   'organis': 0.06,
#   'may': 0.06,
#   'year': 0.06}}

# %%
def doc_frequency(freq_matrix):
    doc_table={}
    for sent, tf_table in freq_matrix.items():
        for word in tf_table.keys():
            if word not in doc_table.keys():
                doc_table[word]=1
            else:
                doc_table[word]+=1
    return doc_table

# %%
doc_matrix=doc_frequency(freq_matrix)
doc_matrix
# Out:
# {'narendra': 3,
#  'damodarda': 2,
#  'modi': 53,
#  'indian': 6,
#  'politician': 1,
#  'serv': 1,
#  '14th': 1,
#  'current': 1,
#  'prime': 3,
#  'minist': 5,
#  'india': 6,
#  'sinc': 3,
#  '2014': 4,
#  'chief': 2,
#  'gujarat': 17,
#  '2001': 3,
#  'member': 6,
#  'parliament': 2,
#  'varanasi': 1,
#  'bharatiya': 2,
#  'janata': 1,
#  'parti': 8,
#  'bjp': 14,
#  'nation': 6,
#  'democrat': 2,
#  'allianc': 1,
#  'nda': 1,
#  'also': 5,
#  'rashtriya': 2,
#  'swayamsevak': 2,
#  'sangh': 4,
#  'rss': 14,
#  'hindu': 4,
#  'nationalist': 2,
#  'volunt': 1,
#  'organis': 7,
#  'first': 4,
#  'born': 4,
#  'independ': 1,
#  '1947': 1,
#  'second': 1,
#  'non-congress': 1,
#  'one': 1,
#  'win': 2,
#  'two': 3,
#  'consecut': 1,
#  'term': 1,
#  'atal': 2,
#  'bihari': 2,
#  'vajpaye': 2,
#  'outsid': 1,
#  'congress': 2,
#  'major': 3,
#  'lok': 4,
#  'sabha': 3,
#  'rais': 3,
#  'vadnagar': 5,
#  'small': 1,
#  'town': 1,
#  'northeastern': 1,
#  'complet': 2,
#  'secondari': 2,
#  'educ': 4,
#  'said': 2,
#  'help': 4,
#  'father': 2,
#  'sell': 2,
#  'tea': 2,
#  'local': 2,
#  'railway': 2,
#  'station': 2,
#  'introduc': 3,
#  'age': 2,
#  'eight': 2,
#  'left': 2,
#  'home': 2,
#  'soon': 3,
#  'marriag': 3,
#  'jashodaben': 3,
#  'chamanl': 1,
#  'publicli': 2,
#  'acknowledg': 1,
#  'mani': 3,
#  'decad': 2,
#  'later': 6,
#  'assert': 1,
#  'travel': 5,
#  'around': 1,
#  'year': 8,
#  'visit': 3,
#  'number': 1,
#  'religi': 1,
#  'centr': 1,
#  'upon': 1,
#  'return': 4,
#  '1971': 3,
#  'becam': 6,
#  'full-tim': 2,
#  'worker': 1,
#  'dure': 5,
#  'state': 5,
#  'emerg': 7,
#  'impos': 1,
#  'across': 3,
#  'countri': 2,
#  '1975': 2,
#  'went': 4,
#  'hide': 1,
#  'assign': 2,
#  '1985': 2,
#  'held': 1,
#  'sever': 2,
#  'posit': 2,
#  'within': 3,
#  'hierarchi': 1,
#  'rise': 1,
#  'rank': 1,
#  'gener': 5,
#  'secretari': 6,
#  'appoint': 1,
#  'sangharsh': 2,
#  'samiti': 1,
#  'committe': 3,
#  'co-ordin': 1,
#  'opposit': 1,
#  'elect': 13,
#  'legisl': 1,
#  'assembl': 3,
#  'administr': 3,
#  'citizenship': 1,
#  'amend': 1,
#  'act': 1,
#  'result': 2,
#  'widespread': 1,
#  'protest': 2,
#  'suprem': 1,
#  'court-appoint': 1,
#  'special': 2,
#  'investig': 1,
#  'team': 1,
#  'found': 3,
#  'evid': 2,
#  'initi': 2,
#  'prosecut': 1,
#  'proceed': 1,
#  'person': 1,
#  'polici': 1,
#  'credit': 2,
#  'encourag': 1,
#  'econom': 1,
#  'growth': 1,
#  'receiv': 3,
#  'prais': 1,
#  'led': 4,
#  'gave': 1,
#  'lower': 1,
#  'hous': 2,
#  'time': 3,
#  'ani': 1,
#  'singl': 1,
#  '1984': 1,
#  'tri': 1,
#  'foreign': 1,
#  'direct': 1,
#  'invest': 1,
#  'economi': 1,
#  'reduc': 1,
#  'spend': 1,
#  'healthcar': 1,
#  'social': 2,
#  'welfar': 1,
#  'programm': 1,
#  'attempt': 1,
#  'improv': 1,
#  'effici': 1,
#  'bureaucraci': 1,
#  'centralis': 1,
#  'power': 2,
#  'abolish': 2,
#  'plan': 2,
#  'commiss': 1,
#  'began': 2,
#  'high-profil': 1,
#  'sanit': 1,
#  'campaign': 3,
#  'controversi': 2,
#  'demonetis': 1,
#  'high-denomin': 1,
#  'banknot': 1,
#  'weaken': 1,
#  'environment': 1,
#  'labour': 1,
#  'law': 1,
#  'tenur': 1,
#  'experienc': 1,
#  'backslid': 1,
#  'follow': 3,
#  'victori': 2,
#  '2019': 1,
#  'revok': 1,
#  'statu': 1,
#  'jammu': 1,
#  'kashmir': 1,
#  'describ': 6,
#  'engin': 1,
#  'polit': 12,
#  'realign': 1,
#  'toward': 1,
#  'right-w': 1,
#  'remain': 4,
#  'figur': 2,
#  'domest': 1,
#  'intern': 1,
#  'belief': 1,
#  'alleg': 1,
#  'role': 3,
#  '2002': 1,
#  'riot': 1,
#  'cite': 2,
#  'exclusionari': 1,
#  'agenda': 1,
#  'earli': 5,
#  'life': 2,
#  'septemb': 1,
#  '1950': 1,
#  'gujarati': 2,
#  'famili': 3,
#  'grocer': 1,
#  'mehsana': 1,
#  'district': 1,
#  'bombay': 1,
#  'present-day': 1,
#  'third': 2,
#  'six': 1,
#  'children': 1,
#  'mulchand': 1,
#  'c.â€‰1915â€': 1,
#  '1989': 1,
#  'hiraben': 1,
#  'c.â€‰1920': 1,
#  'belong': 1,
#  'modh-ghanchi-t': 1,
#  'oil-press': 1,
#  'commun': 1,
#  'categoris': 1,
#  'backward': 2,
#  'class': 4,
#  'govern': 5,
#  'fals': 1,
#  'accus': 1,
#  'mayawati': 1,
#  'cast': 2,
#  'obc': 1,
#  'list': 1,
#  'tool': 1,
#  'child': 1,
#  'ran': 1,
#  'stall': 1,
#  'brother': 1,
#  'near': 2,
#  'terminu': 1,
#  'higher': 1,
#  '1967': 1,
#  'teacher': 2,
#  'averag': 1,
#  'student': 3,
#  'keen': 1,
#  'debat': 2,
#  'interest': 1,
#  'theatr': 1,
#  'gift': 1,
#  'rhetor': 1,
#  'note': 1,
#  'thi': 6,
#  'prefer': 1,
#  'play': 2,
#  'larger-than-lif': 1,
#  'charact': 1,
#  'theatric': 1,
#  'product': 1,
#  'influenc': 2,
#  'imag': 1,
#  'old': 1,
#  'attend': 1,
#  'shakha': 1,
#  'train': 2,
#  'session': 1,
#  'met': 3,
#  'lakshmanrao': 1,
#  'inamdar': 5,
#  'popularli': 1,
#  'known': 2,
#  'vakil': 1,
#  'saheb': 1,
#  'induct': 1,
#  'balswayamsevak': 1,
#  'junior': 1,
#  'cadet': 1,
#  'mentor': 2,
#  'vasant': 1,
#  'gajendragadkar': 1,
#  'nathal': 1,
#  'jaghda': 1,
#  'jana': 2,
#  'leader': 3,
#  'unit': 2,
#  '1980': 1,
#  'custom': 1,
#  'tradit': 1,
#  'arrang': 1,
#  'betroth': 1,
#  'girl': 1,
#  'chimanl': 1,
#  'lead': 2,
#  'afterward': 2,
#  'abandon': 1,
#  'bride': 1,
#  'coupl': 2,
#  'separ': 1,
#  'live': 2,
#  'neither': 1,
#  'marri': 2,
#  'unment': 1,
#  'public': 1,
#  'pronounc': 1,
#  'april': 1,
#  'shortli': 3,
#  'befor': 4,
#  'swept': 1,
#  'affirm': 1,
#  'spous': 1,
#  'estrang': 1,
#  'spent': 1,
#  'ensu': 1,
#  'northern': 1,
#  'north-eastern': 1,
#  'though': 1,
#  'detail': 1,
#  'interview': 1,
#  'ashram': 2,
#  'swami': 1,
#  'vivekananda': 2,
#  'belur': 2,
#  'math': 2,
#  'kolkata': 1,
#  'advaita': 1,
#  'ashrama': 1,
#  'almora': 2,
#  'ramakrishna': 2,
#  'mission': 1,
#  'rajkot': 1,
#  'onli': 1,
#  'short': 3,
#  'lack': 1,
#  'requir': 1,
#  'colleg': 1,
#  'larg': 1,
#  'summer': 1,
#  '1968': 1,
#  'reach': 1,
#  'turn': 1,
#  'away': 1,
#  'wander': 1,
#  'calcutta': 1,
#  'west': 1,
#  'bengal': 1,
#  'assam': 1,
#  'stop': 2,
#  'siliguri': 1,
#  'guwahati': 1,
#  'reject': 1,
#  'back': 1,
#  'via': 1,
#  'delhi': 7,
#  'rajasthan': 1,
#  '1968â€': 1,
#  'sometim': 1,
#  'late': 1,
#  '1969': 1,
#  '1970': 1,
#  'brief': 2,
#  'leav': 1,
#  'ahmedabad': 5,
#  'uncl': 2,
#  'work': 4,
#  'latter': 1,
#  'canteen': 1,
#  'road': 1,
#  'transport': 1,
#  'corpor': 1,
#  'renew': 1,
#  'acquaint': 1,
#  'base': 1,
#  'hedgewar': 1,
#  'bhavan': 1,
#  'headquart': 1,
#  'citi': 1,
#  'activ': 3,
#  'adult': 1,
#  'join': 1,
#  'satyagraha': 1,
#  'enlist': 1,
#  'battlefield': 1,
#  'indira': 2,
#  'gandhi': 2,
#  'central': 2,
#  'disallow': 1,
#  'open': 2,
#  'support': 2,
#  'mukti': 1,
#  'bahini': 1,
#  'put': 2,
#  'tihar': 1,
#  'jail': 1,
#  'period': 2,
#  'indo-pakistani': 1,
#  'war': 2,
#  'pracharak': 2,
#  'took': 2,
#  'part': 2,
#  'non-viol': 1,
#  'new': 2,
#  'arrest': 2,
#  'reason': 2,
#  'would': 1,
#  'co-author': 1,
#  'biographi': 1,
#  'publish': 1,
#  '1978': 2,
#  'bachelor': 1,
#  'art': 2,
#  'degre': 2,
#  'scienc': 2,
#  'school': 2,
#  'learn': 2,
#  'univers': 2,
#  'graduat': 2,
#  'five': 1,
#  '1983': 1,
#  'master': 1,
#  'extern': 1,
#  'distanc': 1,
#  'career': 1,
#  'june': 1,
#  'declar': 1,
#  'last': 1,
#  '1977': 1,
#  'wrote': 1,
#  'book': 1,
#  'struggl': 1,
#  'event': 1,
#  'ban': 1,
#  'forc': 2,
#  'underground': 1,
#  'frequent': 1,
#  'disguis': 2,
#  'avoid': 1,
#  'involv': 2,
#  'print': 1,
#  'pamphlet': 1,
#  'oppos': 1,
#  'send': 1,
#  'demonstr': 1,
#  'creat': 1,
#  'network': 1,
#  'safe': 1,
#  'individu': 1,
#  'want': 1,
#  'fund': 1,
#  'refuge': 1,
#  'activist': 2,
#  'among': 1,
#  'peopl': 1,
#  'trade': 1,
#  'unionist': 1,
#  'socialist': 1,
#  'georg': 1,
#  'fernand': 1,
#  'well': 1,
#  'often': 1,
#  'move': 1,
#  'onc': 1,
#  'dress': 1,
#  'monk': 1,
#  'sikh': 1,
#  'sambhag': 1,
#  'region': 1,
#  'overse': 1,
#  'area': 1,
#  'surat': 1,
#  'vadodara': 1,
#  '1979': 1,
#  'research': 1,
#  'write': 1,
#  'version': 1,
#  'histori': 1,
#  '1987': 2,
#  'municip': 1,
#  'comfort': 1,
#  'biograph': 1,
#  'advani': 3,
#  'presid': 1,
#  '1986': 1,
#  'decid': 1,
#  'place': 1,
#  'import': 1,
#  'select': 2,
#  'rose': 1,
#  'name': 1,
#  '1990': 1,
#  'ram': 1,
#  'rath': 1,
#  'yatra': 1,
#  'murli': 1,
#  'manohar': 1,
#  'joshi': 1,
#  '1991â€': 1,
#  'ekta': 1,
#  'journey': 1,
#  'uniti': 1,
#  'howev': 1,
#  'break': 1,
#  '1992': 1,
#  'instead': 1,
#  'establish': 1,
#  'friction': 1,
#  'shankersinh': 2,
#  'vaghela': 3,
#  'decis': 1,
#  'elector': 1,
#  '1994': 1,
#  'partli': 1,
#  'insist': 1,
#  'strategi': 2,
#  'consid': 1,
#  '1995': 1,
#  'novemb': 1,
#  'transfer': 1,
#  'assum': 1,
#  'respons': 1,
#  'haryana': 1,
#  'himach': 1,
#  'pradesh': 1,
#  'promin': 1,
#  'defect': 1,
#  'inc': 1,
#  'lose': 1,
#  'parliamentari': 1,
#  'seat': 1,
#  '1998': 2,
#  'favour': 1,
#  'keshubhai': 1,
#  'patel': 1,
#  'end': 1,
#  'faction': 1,
#  'divis': 1,
#  'key': 1,
#  'overal': 1,
#  'promot': 1,
#  'may': 1}

# %%
def idf_matrix(freq_matrix,doc_per_word):
    total_doc=len(freq_matrix.keys())
    tf_matrix={}
    for sent, tf_table in freq_matrix.items():
        freq_table={}
        for word in tf_table.keys():
            freq_table[word]=round(math.log10(total_doc/doc_per_word[word]),2)
        tf_matrix[sent]=freq_table
    return tf_matrix

# %%
idf1_matrix=idf_matrix(freq_matrix,doc_matrix)
idf1_matrix
# Out:
# {'Narendra Damoda': {'narendra': 1.39,
#   'damodarda': 1.56,
#   'modi': 0.14,
#   'indian': 1.09,
#   'politician': 1.86,
#   'serv': 1.86,
#   '14th': 1.86,
#   'current': 1.86,
#   'prime': 1.39,
#   'minist': 1.16,
#   'india': 1.09,
#   'sinc': 1.39,
#   '2014': 1.26},
#  'He was the chie': {'chief': 1.56,
#   'minist': 1.16,
#   'gujarat': 0.63,
#   '2001': 1.39,
#   '2014': 1.26,
#   'member': 1.09,
#   'parliament': 1.56,
#   'varanasi': 1.86},
#  'Modi is a membe': {'modi': 0.14,
#   'member': 1.09,
#   'bharatiya': 1.56,
#   'janata': 1.86,
#   'parti': 0.96,
#   'bjp': 0.72,
#   'nation': 1.09,
#   'democrat': 1.56,
#   'allianc': 1.86,
#   'nda': 1.86},
#  'He is also a me': {'also': 1.16,
#   'member': 1.09,
#   'rashtriya': 1.56,
#   'swayamsevak': 1.56,
#   'sangh': 1.26,
#   'rss': 0.72,
#   'hindu': 1.26,
#   'nationalist': 1.56,
#   'volunt': 1.86,
#   'organis': 1.02},
#  'He is the first': {'first': 1.26,
#   'prime': 1.39,
#   'minist': 1.16,
#   'born': 1.26,
#   'india': 1.09,
#   'independ': 1.86,
#   '1947': 1.86,
#   'second': 1.86,
#   'non-congress': 1.86,
#   'one': 1.86,
#   'win': 1.56,
#   'two': 1.39,
#   'consecut': 1.86,
#   'term': 1.86,
#   'atal': 1.56,
#   'bihari': 1.56,
#   'vajpaye': 1.56,
#   'outsid': 1.86,
#   'congress': 1.56,
#   'major': 1.39,
#   'lok': 1.26,
#   'sabha': 1.39},
#  'Born and raised': {'born': 1.26,
#   'rais': 1.39,
#   'vadnagar': 1.16,
#   'small': 1.86,
#   'town': 1.86,
#   'northeastern': 1.86,
#   'gujarat': 0.63,
#   'modi': 0.14,
#   'complet': 1.56,
#   'secondari': 1.56,
#   'educ': 1.26,
#   'said': 1.56,
#   'help': 1.26,
#   'father': 1.56,
#   'sell': 1.56,
#   'tea': 1.56,
#   'local': 1.56,
#   'railway': 1.56,
#   'station': 1.56},
#  'He was introduc': {'introduc': 1.39,
#   'rss': 0.72,
#   'age': 1.56,
#   'eight': 1.56},
#  'Modi left home ': {'modi': 0.14,
#   'left': 1.56,
#   'home': 1.56,
#   'age': 1.56,
#   'soon': 1.39,
#   'marriag': 1.39,
#   'jashodaben': 1.39,
#   'chamanl': 1.86,
#   'publicli': 1.56,
#   'acknowledg': 1.86,
#   'mani': 1.39,
#   'decad': 1.56,
#   'later': 1.09},
#  'Modi has assert': {'modi': 0.14,
#   'assert': 1.86,
#   'travel': 1.16,
#   'around': 1.86,
#   'india': 1.09,
#   'two': 1.39,
#   'year': 0.96,
#   'visit': 1.39,
#   'number': 1.86,
#   'religi': 1.86,
#   'centr': 1.86},
#  'Upon his return': {'upon': 1.86,
#   'return': 1.26,
#   'gujarat': 0.63,
#   '1971': 1.39,
#   'becam': 1.09,
#   'full-tim': 1.56,
#   'worker': 1.86,
#   'rss': 0.72},
#  'During the stat': {'dure': 1.16,
#   'state': 1.16,
#   'emerg': 1.02,
#   'impos': 1.86,
#   'across': 1.39,
#   'countri': 1.56,
#   '1975': 1.56,
#   'modi': 0.14,
#   'went': 1.26,
#   'hide': 1.86},
#  'The RSS assigne': {'rss': 0.72,
#   'assign': 1.56,
#   'bjp': 0.72,
#   '1985': 1.56,
#   'held': 1.86,
#   'sever': 1.56,
#   'posit': 1.56,
#   'within': 1.39,
#   'parti': 0.96,
#   'hierarchi': 1.86,
#   '2001': 1.39,
#   'rise': 1.86,
#   'rank': 1.86,
#   'gener': 1.16,
#   'secretari': 1.09},
#  'Modi was appoin': {'modi': 0.14,
#   'appoint': 1.86,
#   'gener': 1.16,
#   'secretari': 1.09,
#   'gujarat': 0.63,
#   'lok': 1.26,
#   'sangharsh': 1.56,
#   'samiti': 1.86,
#   'rss': 0.72,
#   'committe': 1.39,
#   'co-ordin': 1.86,
#   'opposit': 1.86,
#   'emerg': 1.02},
#  'Modi was electe': {'modi': 0.14,
#   'elect': 0.75,
#   'legisl': 1.86,
#   'assembl': 1.39,
#   'soon': 1.39},
#  'His administrat': {'administr': 1.39,
#   'also': 1.16,
#   'introduc': 1.39,
#   'citizenship': 1.86,
#   'amend': 1.86,
#   'act': 1.86,
#   'result': 1.56,
#   'widespread': 1.86,
#   'protest': 1.56,
#   'across': 1.39,
#   'countri': 1.56},
#  'A Supreme Court': {'suprem': 1.86,
#   'court-appoint': 1.86,
#   'special': 1.56,
#   'investig': 1.86,
#   'team': 1.86,
#   'found': 1.39,
#   'evid': 1.56,
#   'initi': 1.56,
#   'prosecut': 1.86,
#   'proceed': 1.86,
#   'modi': 0.14,
#   'person': 1.86},
#  'His policies as': {'polici': 1.86,
#   'chief': 1.56,
#   'minist': 1.16,
#   'credit': 1.56,
#   'encourag': 1.86,
#   'econom': 1.86,
#   'growth': 1.86,
#   'receiv': 1.39,
#   'prais': 1.86},
#  'Modi led the BJ': {'modi': 0.14,
#   'led': 1.26,
#   'bjp': 0.72,
#   '2014': 1.26,
#   'gener': 1.16,
#   'elect': 0.75,
#   'gave': 1.86,
#   'parti': 0.96,
#   'major': 1.39,
#   'indian': 1.09,
#   'lower': 1.86,
#   'hous': 1.56,
#   'parliament': 1.56,
#   'lok': 1.26,
#   'sabha': 1.39,
#   'first': 1.26,
#   'time': 1.39,
#   'ani': 1.86,
#   'singl': 1.86,
#   'sinc': 1.39,
#   '1984': 1.86},
#  "Modi's administ": {'modi': 0.14,
#   'administr': 1.39,
#   'tri': 1.86,
#   'rais': 1.39,
#   'foreign': 1.86,
#   'direct': 1.86,
#   'invest': 1.86,
#   'indian': 1.09,
#   'economi': 1.86,
#   'reduc': 1.86,
#   'spend': 1.86,
#   'healthcar': 1.86,
#   'social': 1.56,
#   'welfar': 1.86,
#   'programm': 1.86},
#  'Modi has attemp': {'modi': 0.14,
#   'attempt': 1.86,
#   'improv': 1.86,
#   'effici': 1.86,
#   'bureaucraci': 1.86,
#   'centralis': 1.86,
#   'power': 1.56,
#   'abolish': 1.56,
#   'plan': 1.56,
#   'commiss': 1.86},
#  'He began a high': {'began': 1.56,
#   'high-profil': 1.86,
#   'sanit': 1.86,
#   'campaign': 1.39,
#   'initi': 1.56,
#   'controversi': 1.56,
#   'demonetis': 1.86,
#   'high-denomin': 1.86,
#   'banknot': 1.86,
#   'weaken': 1.86,
#   'abolish': 1.56,
#   'environment': 1.86,
#   'labour': 1.86,
#   'law': 1.86},
#  "Under Modi's te": {'modi': 0.14,
#   'tenur': 1.86,
#   'india': 1.09,
#   'experienc': 1.86,
#   'democrat': 1.56,
#   'backslid': 1.86},
#  'Following his p': {'follow': 1.39,
#   'parti': 0.96,
#   'victori': 1.56,
#   '2019': 1.86,
#   'gener': 1.16,
#   'elect': 0.75,
#   'administr': 1.39,
#   'revok': 1.86,
#   'special': 1.56,
#   'statu': 1.86,
#   'jammu': 1.86,
#   'kashmir': 1.86},
#  'Described as en': {'describ': 1.09,
#   'engin': 1.86,
#   'polit': 0.78,
#   'realign': 1.86,
#   'toward': 1.86,
#   'right-w': 1.86,
#   'modi': 0.14,
#   'remain': 1.26,
#   'figur': 1.56,
#   'controversi': 1.56,
#   'domest': 1.86,
#   'intern': 1.86,
#   'hindu': 1.26,
#   'nationalist': 1.56,
#   'belief': 1.86,
#   'alleg': 1.86,
#   'role': 1.39,
#   'dure': 1.16,
#   '2002': 1.86,
#   'gujarat': 0.63,
#   'riot': 1.86,
#   'cite': 1.56,
#   'evid': 1.56,
#   'exclusionari': 1.86,
#   'social': 1.56,
#   'agenda': 1.86},
#  'Early life and ': {'earli': 1.16,
#   'life': 1.56,
#   'educ': 1.26,
#   'narendra': 1.39,
#   'modi': 0.14,
#   'born': 1.26,
#   'septemb': 1.86,
#   '1950': 1.86,
#   'gujarati': 1.56,
#   'hindu': 1.26,
#   'famili': 1.39,
#   'grocer': 1.86,
#   'vadnagar': 1.16,
#   'mehsana': 1.86,
#   'district': 1.86,
#   'bombay': 1.86,
#   'state': 1.16,
#   'present-day': 1.86,
#   'gujarat': 0.63},
#  'He was the thir': {'third': 1.56,
#   'six': 1.86,
#   'children': 1.86,
#   'born': 1.26,
#   'damodarda': 1.56,
#   'mulchand': 1.86,
#   'modi': 0.14,
#   'c.â€‰1915â€': 1.86,
#   '1989': 1.86,
#   'hiraben': 1.86,
#   'c.â€‰1920': 1.86},
#  "Modi's family b": {'modi': 0.14,
#   'famili': 1.39,
#   'belong': 1.86,
#   'modh-ghanchi-t': 1.86,
#   'oil-press': 1.86,
#   'commun': 1.86,
#   'categoris': 1.86,
#   'backward': 1.56,
#   'class': 1.26,
#   'indian': 1.09,
#   'govern': 1.16},
#  'He was falsely ': {'fals': 1.86,
#   'accus': 1.86,
#   'mayawati': 1.86,
#   'cast': 1.56,
#   'backward': 1.56,
#   'class': 1.26,
#   'obc': 1.86,
#   'list': 1.86,
#   'polit': 0.78,
#   'tool': 1.86},
#  'As a child, Mod': {'child': 1.86,
#   'modi': 0.14,
#   'said': 1.56,
#   'help': 1.26,
#   'father': 1.56,
#   'sell': 1.56,
#   'tea': 1.56,
#   'vadnagar': 1.16,
#   'railway': 1.56,
#   'station': 1.56,
#   'later': 1.09,
#   'ran': 1.86,
#   'stall': 1.86,
#   'brother': 1.86,
#   'near': 1.56,
#   'terminu': 1.86},
#  'Modi completed ': {'modi': 0.14,
#   'complet': 1.56,
#   'higher': 1.86,
#   'secondari': 1.56,
#   'educ': 1.26,
#   'vadnagar': 1.16,
#   '1967': 1.86,
#   'teacher': 1.56,
#   'describ': 1.09,
#   'averag': 1.86,
#   'student': 1.39,
#   'keen': 1.86,
#   'debat': 1.56,
#   'interest': 1.86,
#   'theatr': 1.86},
#  'Modi had an ear': {'modi': 0.14,
#   'earli': 1.16,
#   'gift': 1.86,
#   'rhetor': 1.86,
#   'debat': 1.56,
#   'teacher': 1.56,
#   'student': 1.39,
#   'note': 1.86,
#   'thi': 1.09},
#  'Modi preferred ': {'modi': 0.14,
#   'prefer': 1.86,
#   'play': 1.56,
#   'larger-than-lif': 1.86,
#   'charact': 1.86,
#   'theatric': 1.86,
#   'product': 1.86,
#   'influenc': 1.56,
#   'polit': 0.78,
#   'imag': 1.86},
#  'When eight year': {'eight': 1.56,
#   'year': 0.96,
#   'old': 1.86,
#   'modi': 0.14,
#   'introduc': 1.39,
#   'rashtriya': 1.56,
#   'swayamsevak': 1.56,
#   'sangh': 1.26,
#   'rss': 0.72,
#   'began': 1.56,
#   'attend': 1.86,
#   'local': 1.56,
#   'shakha': 1.86,
#   'train': 1.56,
#   'session': 1.86},
#  'There, Modi met': {'modi': 0.14,
#   'met': 1.39,
#   'lakshmanrao': 1.86,
#   'inamdar': 1.16,
#   'popularli': 1.86,
#   'known': 1.56,
#   'vakil': 1.86,
#   'saheb': 1.86,
#   'induct': 1.86,
#   'balswayamsevak': 1.86,
#   'junior': 1.86,
#   'cadet': 1.86,
#   'rss': 0.72,
#   'becam': 1.09,
#   'polit': 0.78,
#   'mentor': 1.56},
#  'While Modi was ': {'modi': 0.14,
#   'train': 1.56,
#   'rss': 0.72,
#   'also': 1.16,
#   'met': 1.39,
#   'vasant': 1.86,
#   'gajendragadkar': 1.86,
#   'nathal': 1.86,
#   'jaghda': 1.86,
#   'bharatiya': 1.56,
#   'jana': 1.56,
#   'sangh': 1.26,
#   'leader': 1.39,
#   'found': 1.39,
#   'member': 1.09,
#   'bjp': 0.72,
#   'gujarat': 0.63,
#   'unit': 1.56,
#   '1980': 1.86},
#  'In a custom tra': {'custom': 1.86,
#   'tradit': 1.86,
#   'narendra': 1.39,
#   'modi': 0.14,
#   'cast': 1.56,
#   'famili': 1.39,
#   'arrang': 1.86,
#   'betroth': 1.86,
#   'girl': 1.86,
#   'jashodaben': 1.39,
#   'chimanl': 1.86,
#   'lead': 1.56,
#   'marriag': 1.39},
#  'Soon afterwards': {'soon': 1.39,
#   'afterward': 1.56,
#   'abandon': 1.86,
#   'bride': 1.86,
#   'left': 1.56,
#   'home': 1.56,
#   'coupl': 1.56,
#   'lead': 1.56,
#   'separ': 1.86,
#   'live': 1.56,
#   'neither': 1.86,
#   'marri': 1.56,
#   'marriag': 1.39,
#   'remain': 1.26,
#   'unment': 1.86,
#   'modi': 0.14,
#   'public': 1.86,
#   'pronounc': 1.86,
#   'mani': 1.39,
#   'decad': 1.56},
#  'In April 2014, ': {'april': 1.86,
#   '2014': 1.26,
#   'shortli': 1.39,
#   'befor': 1.26,
#   'nation': 1.09,
#   'elect': 0.75,
#   'swept': 1.86,
#   'power': 1.56,
#   'modi': 0.14,
#   'publicli': 1.56,
#   'affirm': 1.86,
#   'marri': 1.56,
#   'spous': 1.86,
#   'jashodaben': 1.39,
#   'coupl': 1.56,
#   'remain': 1.26,
#   'estrang': 1.86},
#  'Modi spent the ': {'modi': 0.14,
#   'spent': 1.86,
#   'ensu': 1.86,
#   'two': 1.39,
#   'year': 0.96,
#   'travel': 1.16,
#   'across': 1.39,
#   'northern': 1.86,
#   'north-eastern': 1.86,
#   'india': 1.09,
#   'though': 1.86,
#   'detail': 1.86,
#   'went': 1.26,
#   'emerg': 1.02},
#  'In interviews, ': {'interview': 1.86,
#   'modi': 0.14,
#   'describ': 1.09,
#   'visit': 1.39,
#   'hindu': 1.26,
#   'ashram': 1.56,
#   'found': 1.39,
#   'swami': 1.86,
#   'vivekananda': 1.56,
#   'belur': 1.56,
#   'math': 1.56,
#   'near': 1.56,
#   'kolkata': 1.86,
#   'follow': 1.39,
#   'advaita': 1.86,
#   'ashrama': 1.86,
#   'almora': 1.56,
#   'ramakrishna': 1.56,
#   'mission': 1.86,
#   'rajkot': 1.86},
#  'Modi remained o': {'modi': 0.14,
#   'remain': 1.26,
#   'onli': 1.86,
#   'short': 1.39,
#   'time': 1.39,
#   'sinc': 1.39,
#   'lack': 1.86,
#   'requir': 1.86,
#   'colleg': 1.86,
#   'educ': 1.26},
#  'Vivekananda has': {'vivekananda': 1.56,
#   'describ': 1.09,
#   'larg': 1.86,
#   'influenc': 1.56,
#   'modi': 0.14,
#   'life': 1.56},
#  'In the early su': {'earli': 1.16,
#   'summer': 1.86,
#   '1968': 1.86,
#   'modi': 0.14,
#   'reach': 1.86,
#   'belur': 1.56,
#   'math': 1.56,
#   'turn': 1.86,
#   'away': 1.86,
#   'wander': 1.86,
#   'calcutta': 1.86,
#   'west': 1.86,
#   'bengal': 1.86,
#   'assam': 1.86,
#   'stop': 1.56,
#   'siliguri': 1.86,
#   'guwahati': 1.86},
#  'Modi then went ': {'modi': 0.14,
#   'went': 1.26,
#   'ramakrishna': 1.56,
#   'ashram': 1.56,
#   'almora': 1.56,
#   'reject': 1.86,
#   'befor': 1.26,
#   'travel': 1.16,
#   'back': 1.86,
#   'gujarat': 0.63,
#   'via': 1.86,
#   'delhi': 1.02,
#   'rajasthan': 1.86,
#   '1968â€': 1.86},
#  'Sometime in lat': {'sometim': 1.86,
#   'late': 1.86,
#   '1969': 1.86,
#   'earli': 1.16,
#   '1970': 1.86,
#   'modi': 0.14,
#   'return': 1.26,
#   'vadnagar': 1.16,
#   'brief': 1.56,
#   'visit': 1.39,
#   'befor': 1.26,
#   'leav': 1.86,
#   'ahmedabad': 1.16},
#  'There, Modi liv': {'modi': 0.14,
#   'live': 1.56,
#   'uncl': 1.56,
#   'work': 1.26,
#   'latter': 1.86,
#   'canteen': 1.86,
#   'gujarat': 0.63,
#   'state': 1.16,
#   'road': 1.86,
#   'transport': 1.86,
#   'corpor': 1.86},
#  'In Ahmedabad, M': {'ahmedabad': 1.16,
#   'modi': 0.14,
#   'renew': 1.86,
#   'acquaint': 1.86,
#   'inamdar': 1.16,
#   'base': 1.86,
#   'hedgewar': 1.86,
#   'bhavan': 1.86,
#   'rss': 0.72,
#   'headquart': 1.86,
#   'citi': 1.86},
#  "Modi's first kn": {'modi': 0.14,
#   'first': 1.26,
#   'known': 1.56,
#   'polit': 0.78,
#   'activ': 1.39,
#   'adult': 1.86,
#   '1971': 1.39,
#   'join': 1.86,
#   'jana': 1.56,
#   'sangh': 1.26,
#   'satyagraha': 1.86,
#   'delhi': 1.02,
#   'led': 1.26,
#   'atal': 1.56,
#   'bihari': 1.56,
#   'vajpaye': 1.56,
#   'enlist': 1.86,
#   'battlefield': 1.86},
#  'But the Indira ': {'indira': 1.56,
#   'gandhi': 1.56,
#   'led': 1.26,
#   'central': 1.56,
#   'govern': 1.16,
#   'disallow': 1.86,
#   'open': 1.56,
#   'support': 1.56,
#   'mukti': 1.86,
#   'bahini': 1.86,
#   'modi': 0.14,
#   'put': 1.56,
#   'tihar': 1.86,
#   'jail': 1.86,
#   'short': 1.39,
#   'period': 1.56},
#  'After the Indo-': {'indo-pakistani': 1.86,
#   'war': 1.56,
#   '1971': 1.39,
#   'stop': 1.56,
#   'work': 1.26,
#   'uncl': 1.56,
#   'becam': 1.09,
#   'full-tim': 1.56,
#   'pracharak': 1.56,
#   'campaign': 1.39,
#   'rss': 0.72,
#   'inamdar': 1.16},
#  'Shortly before ': {'shortli': 1.39,
#   'befor': 1.26,
#   'war': 1.56,
#   'modi': 0.14,
#   'took': 1.56,
#   'part': 1.56,
#   'non-viol': 1.86,
#   'protest': 1.56,
#   'indian': 1.09,
#   'govern': 1.16,
#   'new': 1.56,
#   'delhi': 1.02,
#   'arrest': 1.56,
#   'thi': 1.09,
#   'cite': 1.56,
#   'reason': 1.56,
#   'inamdar': 1.16,
#   'elect': 0.75,
#   'mentor': 1.56},
#  'Many years late': {'mani': 1.39,
#   'year': 0.96,
#   'later': 1.09,
#   'modi': 0.14,
#   'would': 1.86,
#   'co-author': 1.86,
#   'biographi': 1.86,
#   'inamdar': 1.16,
#   'publish': 1.86,
#   '2001': 1.39},
#  'In 1978 Modi re': {'1978': 1.56,
#   'modi': 0.14,
#   'receiv': 1.39,
#   'bachelor': 1.86,
#   'art': 1.56,
#   'degre': 1.56,
#   'polit': 0.78,
#   'scienc': 1.56,
#   'school': 1.56,
#   'open': 1.56,
#   'learn': 1.56,
#   'univers': 1.56,
#   'delhi': 1.02,
#   'graduat': 1.56,
#   'third': 1.56,
#   'class': 1.26},
#  'Five years late': {'five': 1.86,
#   'year': 0.96,
#   'later': 1.09,
#   '1983': 1.86,
#   'receiv': 1.39,
#   'master': 1.86,
#   'art': 1.56,
#   'degre': 1.56,
#   'polit': 0.78,
#   'scienc': 1.56,
#   'gujarat': 0.63,
#   'univers': 1.56,
#   'graduat': 1.56,
#   'first': 1.26,
#   'class': 1.26,
#   'extern': 1.86,
#   'distanc': 1.86,
#   'learn': 1.56,
#   'student': 1.39},
#  'Early political': {'earli': 1.16,
#   'polit': 0.78,
#   'career': 1.86,
#   'june': 1.86,
#   '1975': 1.56,
#   'prime': 1.39,
#   'minist': 1.16,
#   'indira': 1.56,
#   'gandhi': 1.56,
#   'declar': 1.86,
#   'state': 1.16,
#   'emerg': 1.02,
#   'india': 1.09,
#   'last': 1.86,
#   '1977': 1.86},
#  'During this per': {'dure': 1.16,
#   'thi': 1.09,
#   'period': 1.56,
#   'modi': 0.14,
#   'wrote': 1.86,
#   'book': 1.86,
#   'gujarati': 1.56,
#   'sangharsh': 1.56,
#   'gujarat': 0.63,
#   'struggl': 1.86,
#   'describ': 1.09,
#   'event': 1.86,
#   'emerg': 1.02},
#  'Shortly afterwa': {'shortli': 1.39,
#   'afterward': 1.56,
#   'rss': 0.72,
#   'ban': 1.86},
#  'Modi was forced': {'modi': 0.14,
#   'forc': 1.56,
#   'underground': 1.86,
#   'gujarat': 0.63,
#   'frequent': 1.86,
#   'travel': 1.16,
#   'disguis': 1.56,
#   'avoid': 1.86,
#   'arrest': 1.56},
#  'He became invol': {'becam': 1.09,
#   'involv': 1.56,
#   'print': 1.86,
#   'pamphlet': 1.86,
#   'oppos': 1.86,
#   'govern': 1.16,
#   'send': 1.86,
#   'delhi': 1.02,
#   'organis': 1.02,
#   'demonstr': 1.86},
#  'Modi was also i': {'modi': 0.14,
#   'also': 1.16,
#   'involv': 1.56,
#   'creat': 1.86,
#   'network': 1.86,
#   'safe': 1.86,
#   'hous': 1.56,
#   'individu': 1.86,
#   'want': 1.86,
#   'govern': 1.16,
#   'rais': 1.39,
#   'fund': 1.86,
#   'polit': 0.78,
#   'refuge': 1.86,
#   'activist': 1.56},
#  'Among the peopl': {'among': 1.86,
#   'peopl': 1.86,
#   'met': 1.39,
#   'thi': 1.09,
#   'role': 1.39,
#   'trade': 1.86,
#   'unionist': 1.86,
#   'socialist': 1.86,
#   'activist': 1.56,
#   'georg': 1.86,
#   'fernand': 1.86,
#   'well': 1.86,
#   'sever': 1.56,
#   'nation': 1.09,
#   'polit': 0.78,
#   'figur': 1.56},
#  'In his travels ': {'travel': 1.16,
#   'dure': 1.16,
#   'emerg': 1.02,
#   'modi': 0.14,
#   'often': 1.86,
#   'forc': 1.56,
#   'move': 1.86,
#   'disguis': 1.56,
#   'onc': 1.86,
#   'dress': 1.86,
#   'monk': 1.86,
#   'sikh': 1.86},
#  'Modi became an ': {'modi': 0.14,
#   'becam': 1.09,
#   'rss': 0.72,
#   'sambhag': 1.86,
#   'pracharak': 1.56,
#   'region': 1.86,
#   'organis': 1.02,
#   '1978': 1.56,
#   'overse': 1.86,
#   'activ': 1.39,
#   'area': 1.86,
#   'surat': 1.86,
#   'vadodara': 1.86,
#   '1979': 1.86,
#   'went': 1.26,
#   'work': 1.26,
#   'delhi': 1.02,
#   'put': 1.56,
#   'research': 1.86,
#   'write': 1.86,
#   'version': 1.86,
#   'histori': 1.86,
#   'emerg': 1.02},
#  'He returned to ': {'return': 1.26,
#   'gujarat': 0.63,
#   'short': 1.39,
#   'later': 1.09,
#   'assign': 1.56,
#   'rss': 0.72,
#   'bjp': 0.72,
#   '1985': 1.56},
#  'In 1987 Modi he': {'1987': 1.56,
#   'modi': 0.14,
#   'help': 1.26,
#   'organis': 1.02,
#   'bjp': 0.72,
#   'campaign': 1.39,
#   'ahmedabad': 1.16,
#   'municip': 1.86,
#   'elect': 0.75,
#   'comfort': 1.86,
#   'plan': 1.56,
#   'describ': 1.09,
#   'reason': 1.56,
#   'result': 1.56,
#   'biograph': 1.86},
#  'After L. K. Adv': {'advani': 1.39,
#   'becam': 1.09,
#   'presid': 1.86,
#   'bjp': 0.72,
#   '1986': 1.86,
#   'rss': 0.72,
#   'decid': 1.86,
#   'place': 1.86,
#   'member': 1.09,
#   'import': 1.86,
#   'posit': 1.56,
#   'within': 1.39,
#   'modi': 0.14,
#   'work': 1.26,
#   'dure': 1.16,
#   'ahmedabad': 1.16,
#   'elect': 0.75,
#   'led': 1.26,
#   'select': 1.56,
#   'thi': 1.09,
#   'role': 1.39,
#   'organis': 1.02,
#   'secretari': 1.09,
#   'gujarat': 0.63,
#   'unit': 1.56,
#   'later': 1.09,
#   '1987': 1.56},
#  'Modi rose withi': {'modi': 0.14,
#   'rose': 1.86,
#   'within': 1.39,
#   'parti': 0.96,
#   'name': 1.86,
#   'member': 1.09,
#   'bjp': 0.72,
#   'nation': 1.09,
#   'elect': 0.75,
#   'committe': 1.39,
#   '1990': 1.86,
#   'help': 1.26,
#   'organis': 1.02,
#   'advani': 1.39,
#   'ram': 1.86,
#   'rath': 1.86,
#   'yatra': 1.86,
#   'murli': 1.86,
#   'manohar': 1.86,
#   'joshi': 1.86,
#   '1991â€': 1.86,
#   'ekta': 1.86,
#   'journey': 1.86,
#   'uniti': 1.86},
#  'However, he too': {'howev': 1.86,
#   'took': 1.56,
#   'brief': 1.56,
#   'break': 1.86,
#   'polit': 0.78,
#   '1992': 1.86,
#   'instead': 1.86,
#   'establish': 1.86,
#   'school': 1.56,
#   'ahmedabad': 1.16,
#   'friction': 1.86,
#   'shankersinh': 1.56,
#   'vaghela': 1.39,
#   'bjp': 0.72,
#   'gujarat': 0.63,
#   'time': 1.39,
#   'also': 1.16,
#   'play': 1.56,
#   'part': 1.56,
#   'thi': 1.09,
#   'decis': 1.86},
#  'Modi returned t': {'modi': 0.14,
#   'return': 1.26,
#   'elector': 1.86,
#   'polit': 0.78,
#   '1994': 1.86,
#   'partli': 1.86,
#   'insist': 1.86,
#   'advani': 1.39,
#   'parti': 0.96,
#   'secretari': 1.09,
#   'strategi': 1.56,
#   'consid': 1.86,
#   'central': 1.56,
#   'bjp': 0.72,
#   'victori': 1.56,
#   '1995': 1.86,
#   'state': 1.16,
#   'assembl': 1.39,
#   'elect': 0.75},
#  'In November of ': {'novemb': 1.86,
#   'year': 0.96,
#   'modi': 0.14,
#   'elect': 0.75,
#   'bjp': 0.72,
#   'nation': 1.09,
#   'secretari': 1.09,
#   'transfer': 1.86,
#   'new': 1.56,
#   'delhi': 1.02,
#   'assum': 1.86,
#   'respons': 1.86,
#   'parti': 0.96,
#   'activ': 1.39,
#   'haryana': 1.86,
#   'himach': 1.86,
#   'pradesh': 1.86},
#  'The following y': {'follow': 1.39,
#   'year': 0.96,
#   'shankersinh': 1.56,
#   'vaghela': 1.39,
#   'promin': 1.86,
#   'bjp': 0.72,
#   'leader': 1.39,
#   'gujarat': 0.63,
#   'defect': 1.86,
#   'indian': 1.09,
#   'nation': 1.09,
#   'congress': 1.56,
#   'inc': 1.86,
#   'lose': 1.86,
#   'parliamentari': 1.86,
#   'seat': 1.86,
#   'lok': 1.26,
#   'sabha': 1.39,
#   'elect': 0.75},
#  'Modi, on the se': {'modi': 0.14,
#   'select': 1.56,
#   'committe': 1.39,
#   '1998': 1.56,
#   'assembl': 1.39,
#   'elect': 0.75,
#   'gujarat': 0.63,
#   'favour': 1.86,
#   'support': 1.56,
#   'bjp': 0.72,
#   'leader': 1.39,
#   'keshubhai': 1.86,
#   'patel': 1.86,
#   'vaghela': 1.39,
#   'end': 1.86,
#   'faction': 1.86,
#   'divis': 1.86,
#   'parti': 0.96},
#  'His strategy wa': {'strategi': 1.56,
#   'credit': 1.56,
#   'key': 1.86,
#   'bjp': 0.72,
#   'win': 1.56,
#   'overal': 1.86,
#   'major': 1.39,
#   '1998': 1.56,
#   'elect': 0.75,
#   'modi': 0.14,
#   'promot': 1.86,
#   'gener': 1.16,
#   'secretari': 1.09,
#   'organis': 1.02,
#   'may': 1.86,
#   'year': 0.96}}

# %%
def tf_idf_matrix(tf_matrix,idf_matrix):
    tf_idf_matrix={}
    for (sent1,ft_table1),(sent2,ft_table2) in zip(tf_matrix.items(),idf_matrix.items()):
        freq_table={}
        for (word1,value1),(word2,value2) in zip(ft_table1.items(),ft_table2.items()):
            freq_table[word1]=round(value1*value2,2)
        tf_idf_matrix[sent1]=freq_table
    return tf_idf_matrix

# %%
tf_idf_matrix1=tf_idf_matrix(tf_matrix1,idf1_matrix)
tf_idf_matrix1
# Out:
# {'Narendra Damoda': {'narendra': 0.11,
#   'damodarda': 0.12,
#   'modi': 0.01,
#   'indian': 0.09,
#   'politician': 0.15,
#   'serv': 0.15,
#   '14th': 0.15,
#   'current': 0.15,
#   'prime': 0.11,
#   'minist': 0.09,
#   'india': 0.09,
#   'sinc': 0.11,
#   '2014': 0.1},
#  'He was the chie': {'chief': 0.19,
#   'minist': 0.14,
#   'gujarat': 0.08,
#   '2001': 0.17,
#   '2014': 0.15,
#   'member': 0.13,
#   'parliament': 0.19,
#   'varanasi': 0.22},
#  'Modi is a membe': {'modi': 0.01,
#   'member': 0.11,
#   'bharatiya': 0.16,
#   'janata': 0.19,
#   'parti': 0.1,
#   'bjp': 0.07,
#   'nation': 0.11,
#   'democrat': 0.16,
#   'allianc': 0.19,
#   'nda': 0.19},
#  'He is also a me': {'also': 0.12,
#   'member': 0.11,
#   'rashtriya': 0.16,
#   'swayamsevak': 0.16,
#   'sangh': 0.13,
#   'rss': 0.07,
#   'hindu': 0.13,
#   'nationalist': 0.16,
#   'volunt': 0.19,
#   'organis': 0.1},
#  'He is the first': {'first': 0.11,
#   'prime': 0.07,
#   'minist': 0.06,
#   'born': 0.06,
#   'india': 0.05,
#   'independ': 0.09,
#   '1947': 0.09,
#   'second': 0.09,
#   'non-congress': 0.09,
#   'one': 0.09,
#   'win': 0.14,
#   'two': 0.07,
#   'consecut': 0.09,
#   'term': 0.17,
#   'atal': 0.08,
#   'bihari': 0.08,
#   'vajpaye': 0.08,
#   'outsid': 0.09,
#   'congress': 0.08,
#   'major': 0.07,
#   'lok': 0.06,
#   'sabha': 0.07},
#  'Born and raised': {'born': 0.06,
#   'rais': 0.07,
#   'vadnagar': 0.06,
#   'small': 0.09,
#   'town': 0.09,
#   'northeastern': 0.09,
#   'gujarat': 0.03,
#   'modi': 0.01,
#   'complet': 0.08,
#   'secondari': 0.08,
#   'educ': 0.06,
#   'said': 0.08,
#   'help': 0.06,
#   'father': 0.08,
#   'sell': 0.08,
#   'tea': 0.08,
#   'local': 0.08,
#   'railway': 0.08,
#   'station': 0.08},
#  'He was introduc': {'introduc': 0.35,
#   'rss': 0.18,
#   'age': 0.39,
#   'eight': 0.39},
#  'Modi left home ': {'modi': 0.01,
#   'left': 0.12,
#   'home': 0.12,
#   'age': 0.12,
#   'soon': 0.11,
#   'marriag': 0.11,
#   'jashodaben': 0.11,
#   'chamanl': 0.15,
#   'publicli': 0.12,
#   'acknowledg': 0.15,
#   'mani': 0.11,
#   'decad': 0.12,
#   'later': 0.09},
#  'Modi has assert': {'modi': 0.01,
#   'assert': 0.17,
#   'travel': 0.1,
#   'around': 0.17,
#   'india': 0.1,
#   'two': 0.13,
#   'year': 0.09,
#   'visit': 0.13,
#   'number': 0.17,
#   'religi': 0.17,
#   'centr': 0.17},
#  'Upon his return': {'upon': 0.22,
#   'return': 0.15,
#   'gujarat': 0.08,
#   '1971': 0.17,
#   'becam': 0.13,
#   'full-tim': 0.19,
#   'worker': 0.22,
#   'rss': 0.09},
#  'During the stat': {'dure': 0.12,
#   'state': 0.12,
#   'emerg': 0.1,
#   'impos': 0.19,
#   'across': 0.14,
#   'countri': 0.16,
#   '1975': 0.16,
#   'modi': 0.01,
#   'went': 0.13,
#   'hide': 0.19},
#  'The RSS assigne': {'rss': 0.05,
#   'assign': 0.11,
#   'bjp': 0.05,
#   '1985': 0.11,
#   'held': 0.13,
#   'sever': 0.11,
#   'posit': 0.11,
#   'within': 0.1,
#   'parti': 0.07,
#   'hierarchi': 0.13,
#   '2001': 0.1,
#   'rise': 0.13,
#   'rank': 0.13,
#   'gener': 0.08,
#   'secretari': 0.08},
#  'Modi was appoin': {'modi': 0.01,
#   'appoint': 0.15,
#   'gener': 0.09,
#   'secretari': 0.09,
#   'gujarat': 0.09,
#   'lok': 0.1,
#   'sangharsh': 0.12,
#   'samiti': 0.15,
#   'rss': 0.06,
#   'committe': 0.11,
#   'co-ordin': 0.15,
#   'opposit': 0.15,
#   'emerg': 0.08},
#  'Modi was electe': {'modi': 0.03,
#   'elect': 0.15,
#   'legisl': 0.37,
#   'assembl': 0.28,
#   'soon': 0.28},
#  'His administrat': {'administr': 0.13,
#   'also': 0.1,
#   'introduc': 0.13,
#   'citizenship': 0.17,
#   'amend': 0.17,
#   'act': 0.17,
#   'result': 0.14,
#   'widespread': 0.17,
#   'protest': 0.14,
#   'across': 0.13,
#   'countri': 0.14},
#  'A Supreme Court': {'suprem': 0.15,
#   'court-appoint': 0.15,
#   'special': 0.12,
#   'investig': 0.15,
#   'team': 0.15,
#   'found': 0.11,
#   'evid': 0.12,
#   'initi': 0.12,
#   'prosecut': 0.15,
#   'proceed': 0.15,
#   'modi': 0.01,
#   'person': 0.15},
#  'His policies as': {'polici': 0.2,
#   'chief': 0.17,
#   'minist': 0.13,
#   'credit': 0.17,
#   'encourag': 0.2,
#   'econom': 0.2,
#   'growth': 0.2,
#   'receiv': 0.15,
#   'prais': 0.2},
#  'Modi led the BJ': {'modi': 0.01,
#   'led': 0.06,
#   'bjp': 0.04,
#   '2014': 0.06,
#   'gener': 0.06,
#   'elect': 0.04,
#   'gave': 0.09,
#   'parti': 0.1,
#   'major': 0.07,
#   'indian': 0.05,
#   'lower': 0.09,
#   'hous': 0.08,
#   'parliament': 0.08,
#   'lok': 0.06,
#   'sabha': 0.07,
#   'first': 0.06,
#   'time': 0.07,
#   'ani': 0.09,
#   'singl': 0.09,
#   'sinc': 0.07,
#   '1984': 0.09},
#  "Modi's administ": {'modi': 0.01,
#   'administr': 0.1,
#   'tri': 0.13,
#   'rais': 0.1,
#   'foreign': 0.13,
#   'direct': 0.13,
#   'invest': 0.13,
#   'indian': 0.08,
#   'economi': 0.13,
#   'reduc': 0.13,
#   'spend': 0.13,
#   'healthcar': 0.13,
#   'social': 0.11,
#   'welfar': 0.13,
#   'programm': 0.13},
#  'Modi has attemp': {'modi': 0.01,
#   'attempt': 0.19,
#   'improv': 0.19,
#   'effici': 0.19,
#   'bureaucraci': 0.19,
#   'centralis': 0.19,
#   'power': 0.16,
#   'abolish': 0.16,
#   'plan': 0.16,
#   'commiss': 0.19},
#  'He began a high': {'began': 0.11,
#   'high-profil': 0.13,
#   'sanit': 0.13,
#   'campaign': 0.1,
#   'initi': 0.11,
#   'controversi': 0.11,
#   'demonetis': 0.13,
#   'high-denomin': 0.13,
#   'banknot': 0.13,
#   'weaken': 0.13,
#   'abolish': 0.11,
#   'environment': 0.13,
#   'labour': 0.13,
#   'law': 0.13},
#  "Under Modi's te": {'modi': 0.02,
#   'tenur': 0.32,
#   'india': 0.19,
#   'experienc': 0.32,
#   'democrat': 0.27,
#   'backslid': 0.32},
#  'Following his p': {'follow': 0.11,
#   'parti': 0.08,
#   'victori': 0.12,
#   '2019': 0.15,
#   'gener': 0.09,
#   'elect': 0.06,
#   'administr': 0.11,
#   'revok': 0.15,
#   'special': 0.12,
#   'statu': 0.15,
#   'jammu': 0.15,
#   'kashmir': 0.15},
#  'Described as en': {'describ': 0.04,
#   'engin': 0.07,
#   'polit': 0.06,
#   'realign': 0.07,
#   'toward': 0.07,
#   'right-w': 0.07,
#   'modi': 0.01,
#   'remain': 0.05,
#   'figur': 0.06,
#   'controversi': 0.06,
#   'domest': 0.07,
#   'intern': 0.07,
#   'hindu': 0.05,
#   'nationalist': 0.06,
#   'belief': 0.07,
#   'alleg': 0.07,
#   'role': 0.06,
#   'dure': 0.05,
#   '2002': 0.07,
#   'gujarat': 0.03,
#   'riot': 0.07,
#   'cite': 0.06,
#   'evid': 0.06,
#   'exclusionari': 0.07,
#   'social': 0.06,
#   'agenda': 0.07},
#  'Early life and ': {'earli': 0.06,
#   'life': 0.08,
#   'educ': 0.06,
#   'narendra': 0.07,
#   'modi': 0.01,
#   'born': 0.06,
#   'septemb': 0.09,
#   '1950': 0.09,
#   'gujarati': 0.08,
#   'hindu': 0.06,
#   'famili': 0.07,
#   'grocer': 0.09,
#   'vadnagar': 0.06,
#   'mehsana': 0.09,
#   'district': 0.09,
#   'bombay': 0.09,
#   'state': 0.06,
#   'present-day': 0.09,
#   'gujarat': 0.03},
#  'He was the thir': {'third': 0.14,
#   'six': 0.17,
#   'children': 0.17,
#   'born': 0.23,
#   'damodarda': 0.14,
#   'mulchand': 0.17,
#   'modi': 0.03,
#   'c.â€‰1915â€': 0.17,
#   '1989': 0.17,
#   'hiraben': 0.17,
#   'c.â€‰1920': 0.17},
#  "Modi's family b": {'modi': 0.01,
#   'famili': 0.13,
#   'belong': 0.17,
#   'modh-ghanchi-t': 0.17,
#   'oil-press': 0.17,
#   'commun': 0.17,
#   'categoris': 0.17,
#   'backward': 0.14,
#   'class': 0.11,
#   'indian': 0.1,
#   'govern': 0.1},
#  'He was falsely ': {'fals': 0.19,
#   'accus': 0.19,
#   'mayawati': 0.19,
#   'cast': 0.16,
#   'backward': 0.16,
#   'class': 0.13,
#   'obc': 0.19,
#   'list': 0.19,
#   'polit': 0.08,
#   'tool': 0.19},
#  'As a child, Mod': {'child': 0.11,
#   'modi': 0.01,
#   'said': 0.19,
#   'help': 0.08,
#   'father': 0.09,
#   'sell': 0.09,
#   'tea': 0.19,
#   'vadnagar': 0.07,
#   'railway': 0.09,
#   'station': 0.09,
#   'later': 0.07,
#   'ran': 0.11,
#   'stall': 0.11,
#   'brother': 0.11,
#   'near': 0.09,
#   'terminu': 0.11},
#  'Modi completed ': {'modi': 0.01,
#   'complet': 0.11,
#   'higher': 0.13,
#   'secondari': 0.11,
#   'educ': 0.09,
#   'vadnagar': 0.08,
#   '1967': 0.13,
#   'teacher': 0.11,
#   'describ': 0.08,
#   'averag': 0.13,
#   'student': 0.1,
#   'keen': 0.13,
#   'debat': 0.11,
#   'interest': 0.13,
#   'theatr': 0.13},
#  'Modi had an ear': {'modi': 0.02,
#   'earli': 0.13,
#   'gift': 0.2,
#   'rhetor': 0.2,
#   'debat': 0.17,
#   'teacher': 0.17,
#   'student': 0.15,
#   'note': 0.2,
#   'thi': 0.12},
#  'Modi preferred ': {'modi': 0.01,
#   'prefer': 0.19,
#   'play': 0.16,
#   'larger-than-lif': 0.19,
#   'charact': 0.19,
#   'theatric': 0.19,
#   'product': 0.19,
#   'influenc': 0.16,
#   'polit': 0.08,
#   'imag': 0.19},
#  'When eight year': {'eight': 0.11,
#   'year': 0.07,
#   'old': 0.13,
#   'modi': 0.01,
#   'introduc': 0.1,
#   'rashtriya': 0.11,
#   'swayamsevak': 0.11,
#   'sangh': 0.09,
#   'rss': 0.05,
#   'began': 0.11,
#   'attend': 0.13,
#   'local': 0.11,
#   'shakha': 0.13,
#   'train': 0.11,
#   'session': 0.13},
#  'There, Modi met': {'modi': 0.01,
#   'met': 0.08,
#   'lakshmanrao': 0.11,
#   'inamdar': 0.07,
#   'popularli': 0.11,
#   'known': 0.09,
#   'vakil': 0.11,
#   'saheb': 0.11,
#   'induct': 0.11,
#   'balswayamsevak': 0.11,
#   'junior': 0.11,
#   'cadet': 0.11,
#   'rss': 0.04,
#   'becam': 0.07,
#   'polit': 0.05,
#   'mentor': 0.09},
#  'While Modi was ': {'modi': 0.01,
#   'train': 0.08,
#   'rss': 0.04,
#   'also': 0.06,
#   'met': 0.07,
#   'vasant': 0.09,
#   'gajendragadkar': 0.09,
#   'nathal': 0.09,
#   'jaghda': 0.09,
#   'bharatiya': 0.08,
#   'jana': 0.08,
#   'sangh': 0.06,
#   'leader': 0.07,
#   'found': 0.07,
#   'member': 0.05,
#   'bjp': 0.04,
#   'gujarat': 0.03,
#   'unit': 0.08,
#   '1980': 0.09},
#  'In a custom tra': {'custom': 0.15,
#   'tradit': 0.15,
#   'narendra': 0.11,
#   'modi': 0.02,
#   'cast': 0.12,
#   'famili': 0.11,
#   'arrang': 0.15,
#   'betroth': 0.15,
#   'girl': 0.15,
#   'jashodaben': 0.11,
#   'chimanl': 0.15,
#   'lead': 0.12,
#   'marriag': 0.11},
#  'Soon afterwards': {'soon': 0.07,
#   'afterward': 0.08,
#   'abandon': 0.09,
#   'bride': 0.09,
#   'left': 0.08,
#   'home': 0.08,
#   'coupl': 0.08,
#   'lead': 0.08,
#   'separ': 0.09,
#   'live': 0.08,
#   'neither': 0.09,
#   'marri': 0.08,
#   'marriag': 0.07,
#   'remain': 0.06,
#   'unment': 0.09,
#   'modi': 0.01,
#   'public': 0.09,
#   'pronounc': 0.09,
#   'mani': 0.07,
#   'decad': 0.08},
#  'In April 2014, ': {'april': 0.11,
#   '2014': 0.08,
#   'shortli': 0.08,
#   'befor': 0.08,
#   'nation': 0.07,
#   'elect': 0.04,
#   'swept': 0.11,
#   'power': 0.09,
#   'modi': 0.01,
#   'publicli': 0.09,
#   'affirm': 0.11,
#   'marri': 0.19,
#   'spous': 0.11,
#   'jashodaben': 0.08,
#   'coupl': 0.09,
#   'remain': 0.08,
#   'estrang': 0.11},
#  'Modi spent the ': {'modi': 0.01,
#   'spent': 0.13,
#   'ensu': 0.13,
#   'two': 0.1,
#   'year': 0.07,
#   'travel': 0.08,
#   'across': 0.1,
#   'northern': 0.13,
#   'north-eastern': 0.13,
#   'india': 0.08,
#   'though': 0.13,
#   'detail': 0.13,
#   'went': 0.09,
#   'emerg': 0.07},
#  'In interviews, ': {'interview': 0.09,
#   'modi': 0.01,
#   'describ': 0.05,
#   'visit': 0.07,
#   'hindu': 0.06,
#   'ashram': 0.08,
#   'found': 0.07,
#   'swami': 0.09,
#   'vivekananda': 0.08,
#   'belur': 0.08,
#   'math': 0.08,
#   'near': 0.08,
#   'kolkata': 0.09,
#   'follow': 0.07,
#   'advaita': 0.09,
#   'ashrama': 0.09,
#   'almora': 0.08,
#   'ramakrishna': 0.08,
#   'mission': 0.09,
#   'rajkot': 0.09},
#  'Modi remained o': {'modi': 0.01,
#   'remain': 0.13,
#   'onli': 0.19,
#   'short': 0.14,
#   'time': 0.14,
#   'sinc': 0.14,
#   'lack': 0.19,
#   'requir': 0.19,
#   'colleg': 0.19,
#   'educ': 0.13},
#  'Vivekananda has': {'vivekananda': 0.27,
#   'describ': 0.19,
#   'larg': 0.32,
#   'influenc': 0.27,
#   'modi': 0.02,
#   'life': 0.27},
#  'In the early su': {'earli': 0.07,
#   'summer': 0.11,
#   '1968': 0.11,
#   'modi': 0.02,
#   'reach': 0.11,
#   'belur': 0.09,
#   'math': 0.09,
#   'turn': 0.11,
#   'away': 0.11,
#   'wander': 0.11,
#   'calcutta': 0.11,
#   'west': 0.11,
#   'bengal': 0.11,
#   'assam': 0.11,
#   'stop': 0.09,
#   'siliguri': 0.11,
#   'guwahati': 0.11},
#  'Modi then went ': {'modi': 0.01,
#   'went': 0.09,
#   'ramakrishna': 0.11,
#   'ashram': 0.11,
#   'almora': 0.11,
#   'reject': 0.13,
#   'befor': 0.09,
#   'travel': 0.08,
#   'back': 0.13,
#   'gujarat': 0.04,
#   'via': 0.13,
#   'delhi': 0.07,
#   'rajasthan': 0.13,
#   '1968â€': 0.13},
#  'Sometime in lat': {'sometim': 0.15,
#   'late': 0.15,
#   '1969': 0.15,
#   'earli': 0.09,
#   '1970': 0.15,
#   'modi': 0.01,
#   'return': 0.1,
#   'vadnagar': 0.09,
#   'brief': 0.12,
#   'visit': 0.11,
#   'befor': 0.1,
#   'leav': 0.15,
#   'ahmedabad': 0.09},
#  'There, Modi liv': {'modi': 0.01,
#   'live': 0.14,
#   'uncl': 0.14,
#   'work': 0.11,
#   'latter': 0.17,
#   'canteen': 0.17,
#   'gujarat': 0.06,
#   'state': 0.1,
#   'road': 0.17,
#   'transport': 0.17,
#   'corpor': 0.17},
#  'In Ahmedabad, M': {'ahmedabad': 0.1,
#   'modi': 0.01,
#   'renew': 0.17,
#   'acquaint': 0.17,
#   'inamdar': 0.1,
#   'base': 0.17,
#   'hedgewar': 0.17,
#   'bhavan': 0.17,
#   'rss': 0.06,
#   'headquart': 0.17,
#   'citi': 0.17},
#  "Modi's first kn": {'modi': 0.01,
#   'first': 0.08,
#   'known': 0.09,
#   'polit': 0.05,
#   'activ': 0.08,
#   'adult': 0.11,
#   '1971': 0.08,
#   'join': 0.11,
#   'jana': 0.09,
#   'sangh': 0.08,
#   'satyagraha': 0.11,
#   'delhi': 0.06,
#   'led': 0.08,
#   'atal': 0.09,
#   'bihari': 0.09,
#   'vajpaye': 0.09,
#   'enlist': 0.11,
#   'battlefield': 0.11},
#  'But the Indira ': {'indira': 0.09,
#   'gandhi': 0.09,
#   'led': 0.08,
#   'central': 0.09,
#   'govern': 0.07,
#   'disallow': 0.11,
#   'open': 0.09,
#   'support': 0.09,
#   'mukti': 0.11,
#   'bahini': 0.11,
#   'modi': 0.01,
#   'put': 0.09,
#   'tihar': 0.11,
#   'jail': 0.11,
#   'short': 0.08,
#   'period': 0.09},
#  'After the Indo-': {'indo-pakistani': 0.15,
#   'war': 0.12,
#   '1971': 0.11,
#   'stop': 0.12,
#   'work': 0.21,
#   'uncl': 0.12,
#   'becam': 0.09,
#   'full-tim': 0.12,
#   'pracharak': 0.12,
#   'campaign': 0.11,
#   'rss': 0.06,
#   'inamdar': 0.09},
#  'Shortly before ': {'shortli': 0.07,
#   'befor': 0.06,
#   'war': 0.08,
#   'modi': 0.01,
#   'took': 0.08,
#   'part': 0.08,
#   'non-viol': 0.09,
#   'protest': 0.08,
#   'indian': 0.05,
#   'govern': 0.06,
#   'new': 0.08,
#   'delhi': 0.05,
#   'arrest': 0.08,
#   'thi': 0.05,
#   'cite': 0.08,
#   'reason': 0.08,
#   'inamdar': 0.06,
#   'elect': 0.04,
#   'mentor': 0.08},
#  'Many years late': {'mani': 0.14,
#   'year': 0.1,
#   'later': 0.11,
#   'modi': 0.01,
#   'would': 0.19,
#   'co-author': 0.19,
#   'biographi': 0.19,
#   'inamdar': 0.12,
#   'publish': 0.19,
#   '2001': 0.14},
#  'In 1978 Modi re': {'1978': 0.09,
#   'modi': 0.01,
#   'receiv': 0.08,
#   'bachelor': 0.11,
#   'art': 0.09,
#   'degre': 0.09,
#   'polit': 0.05,
#   'scienc': 0.09,
#   'school': 0.09,
#   'open': 0.09,
#   'learn': 0.09,
#   'univers': 0.09,
#   'delhi': 0.06,
#   'graduat': 0.09,
#   'third': 0.09,
#   'class': 0.08},
#  'Five years late': {'five': 0.09,
#   'year': 0.05,
#   'later': 0.05,
#   '1983': 0.09,
#   'receiv': 0.07,
#   'master': 0.09,
#   'art': 0.08,
#   'degre': 0.08,
#   'polit': 0.04,
#   'scienc': 0.08,
#   'gujarat': 0.03,
#   'univers': 0.08,
#   'graduat': 0.08,
#   'first': 0.06,
#   'class': 0.06,
#   'extern': 0.09,
#   'distanc': 0.09,
#   'learn': 0.08,
#   'student': 0.07},
#  'Early political': {'earli': 0.08,
#   'polit': 0.05,
#   'career': 0.13,
#   'june': 0.13,
#   '1975': 0.11,
#   'prime': 0.1,
#   'minist': 0.08,
#   'indira': 0.11,
#   'gandhi': 0.11,
#   'declar': 0.13,
#   'state': 0.08,
#   'emerg': 0.07,
#   'india': 0.08,
#   'last': 0.13,
#   '1977': 0.13},
#  'During this per': {'dure': 0.17,
#   'thi': 0.09,
#   'period': 0.12,
#   'modi': 0.01,
#   'wrote': 0.15,
#   'book': 0.15,
#   'gujarati': 0.12,
#   'sangharsh': 0.12,
#   'gujarat': 0.09,
#   'struggl': 0.15,
#   'describ': 0.09,
#   'event': 0.15,
#   'emerg': 0.08},
#  'Shortly afterwa': {'shortli': 0.35,
#   'afterward': 0.39,
#   'rss': 0.18,
#   'ban': 0.47},
#  'Modi was forced': {'modi': 0.02,
#   'forc': 0.17,
#   'underground': 0.2,
#   'gujarat': 0.07,
#   'frequent': 0.2,
#   'travel': 0.13,
#   'disguis': 0.17,
#   'avoid': 0.2,
#   'arrest': 0.17},
#  'He became invol': {'becam': 0.11,
#   'involv': 0.16,
#   'print': 0.19,
#   'pamphlet': 0.19,
#   'oppos': 0.19,
#   'govern': 0.12,
#   'send': 0.19,
#   'delhi': 0.1,
#   'organis': 0.1,
#   'demonstr': 0.19},
#  'Modi was also i': {'modi': 0.01,
#   'also': 0.08,
#   'involv': 0.11,
#   'creat': 0.13,
#   'network': 0.13,
#   'safe': 0.13,
#   'hous': 0.11,
#   'individu': 0.13,
#   'want': 0.13,
#   'govern': 0.08,
#   'rais': 0.1,
#   'fund': 0.13,
#   'polit': 0.05,
#   'refuge': 0.13,
#   'activist': 0.11},
#  'Among the peopl': {'among': 0.11,
#   'peopl': 0.11,
#   'met': 0.08,
#   'thi': 0.07,
#   'role': 0.08,
#   'trade': 0.11,
#   'unionist': 0.11,
#   'socialist': 0.11,
#   'activist': 0.09,
#   'georg': 0.11,
#   'fernand': 0.11,
#   'well': 0.11,
#   'sever': 0.09,
#   'nation': 0.07,
#   'polit': 0.05,
#   'figur': 0.09},
#  'In his travels ': {'travel': 0.09,
#   'dure': 0.09,
#   'emerg': 0.08,
#   'modi': 0.01,
#   'often': 0.15,
#   'forc': 0.12,
#   'move': 0.15,
#   'disguis': 0.12,
#   'onc': 0.32,
#   'dress': 0.15,
#   'monk': 0.15,
#   'sikh': 0.15},
#  'Modi became an ': {'modi': 0.01,
#   'becam': 0.04,
#   'rss': 0.12,
#   'sambhag': 0.07,
#   'pracharak': 0.06,
#   'region': 0.07,
#   'organis': 0.04,
#   '1978': 0.06,
#   'overse': 0.07,
#   'activ': 0.06,
#   'area': 0.07,
#   'surat': 0.07,
#   'vadodara': 0.07,
#   '1979': 0.07,
#   'went': 0.05,
#   'work': 0.11,
#   'delhi': 0.04,
#   'put': 0.06,
#   'research': 0.07,
#   'write': 0.07,
#   'version': 0.07,
#   'histori': 0.07,
#   'emerg': 0.04},
#  'He returned to ': {'return': 0.15,
#   'gujarat': 0.08,
#   'short': 0.17,
#   'later': 0.13,
#   'assign': 0.19,
#   'rss': 0.09,
#   'bjp': 0.09,
#   '1985': 0.19},
#  'In 1987 Modi he': {'1987': 0.11,
#   'modi': 0.02,
#   'help': 0.09,
#   'organis': 0.07,
#   'bjp': 0.09,
#   'campaign': 0.1,
#   'ahmedabad': 0.08,
#   'municip': 0.13,
#   'elect': 0.05,
#   'comfort': 0.13,
#   'plan': 0.11,
#   'describ': 0.08,
#   'reason': 0.11,
#   'result': 0.11,
#   'biograph': 0.13},
#  'After L. K. Adv': {'advani': 0.06,
#   'becam': 0.04,
#   'presid': 0.07,
#   'bjp': 0.08,
#   '1986': 0.07,
#   'rss': 0.03,
#   'decid': 0.07,
#   'place': 0.07,
#   'member': 0.04,
#   'import': 0.07,
#   'posit': 0.06,
#   'within': 0.06,
#   'modi': 0.01,
#   'work': 0.05,
#   'dure': 0.05,
#   'ahmedabad': 0.05,
#   'elect': 0.05,
#   'led': 0.05,
#   'select': 0.06,
#   'thi': 0.04,
#   'role': 0.06,
#   'organis': 0.04,
#   'secretari': 0.04,
#   'gujarat': 0.03,
#   'unit': 0.06,
#   'later': 0.04,
#   '1987': 0.06},
#  'Modi rose withi': {'modi': 0.01,
#   'rose': 0.07,
#   'within': 0.06,
#   'parti': 0.04,
#   'name': 0.07,
#   'member': 0.04,
#   'bjp': 0.03,
#   'nation': 0.04,
#   'elect': 0.03,
#   'committe': 0.06,
#   '1990': 0.22,
#   'help': 0.05,
#   'organis': 0.04,
#   'advani': 0.06,
#   'ram': 0.07,
#   'rath': 0.07,
#   'yatra': 0.15,
#   'murli': 0.07,
#   'manohar': 0.07,
#   'joshi': 0.07,
#   '1991â€': 0.07,
#   'ekta': 0.07,
#   'journey': 0.07,
#   'uniti': 0.07},
#  'However, he too': {'howev': 0.09,
#   'took': 0.08,
#   'brief': 0.08,
#   'break': 0.09,
#   'polit': 0.04,
#   '1992': 0.09,
#   'instead': 0.09,
#   'establish': 0.09,
#   'school': 0.08,
#   'ahmedabad': 0.06,
#   'friction': 0.09,
#   'shankersinh': 0.08,
#   'vaghela': 0.07,
#   'bjp': 0.04,
#   'gujarat': 0.03,
#   'time': 0.07,
#   'also': 0.06,
#   'play': 0.08,
#   'part': 0.08,
#   'thi': 0.05,
#   'decis': 0.09},
#  'Modi returned t': {'modi': 0.02,
#   'return': 0.06,
#   'elector': 0.2,
#   'polit': 0.04,
#   '1994': 0.09,
#   'partli': 0.09,
#   'insist': 0.09,
#   'advani': 0.07,
#   'parti': 0.05,
#   'secretari': 0.05,
#   'strategi': 0.08,
#   'consid': 0.09,
#   'central': 0.08,
#   'bjp': 0.04,
#   'victori': 0.08,
#   '1995': 0.09,
#   'state': 0.06,
#   'assembl': 0.07,
#   'elect': 0.04},
#  'In November of ': {'novemb': 0.11,
#   'year': 0.06,
#   'modi': 0.01,
#   'elect': 0.04,
#   'bjp': 0.04,
#   'nation': 0.07,
#   'secretari': 0.07,
#   'transfer': 0.11,
#   'new': 0.09,
#   'delhi': 0.06,
#   'assum': 0.11,
#   'respons': 0.11,
#   'parti': 0.06,
#   'activ': 0.08,
#   'haryana': 0.11,
#   'himach': 0.11,
#   'pradesh': 0.11},
#  'The following y': {'follow': 0.07,
#   'year': 0.05,
#   'shankersinh': 0.08,
#   'vaghela': 0.07,
#   'promin': 0.09,
#   'bjp': 0.04,
#   'leader': 0.07,
#   'gujarat': 0.03,
#   'defect': 0.09,
#   'indian': 0.05,
#   'nation': 0.05,
#   'congress': 0.17,
#   'inc': 0.09,
#   'lose': 0.09,
#   'parliamentari': 0.09,
#   'seat': 0.09,
#   'lok': 0.06,
#   'sabha': 0.07,
#   'elect': 0.04},
#  'Modi, on the se': {'modi': 0.01,
#   'select': 0.09,
#   'committe': 0.08,
#   '1998': 0.09,
#   'assembl': 0.08,
#   'elect': 0.04,
#   'gujarat': 0.04,
#   'favour': 0.11,
#   'support': 0.17,
#   'bjp': 0.04,
#   'leader': 0.08,
#   'keshubhai': 0.11,
#   'patel': 0.11,
#   'vaghela': 0.08,
#   'end': 0.11,
#   'faction': 0.11,
#   'divis': 0.11,
#   'parti': 0.06},
#  'His strategy wa': {'strategi': 0.09,
#   'credit': 0.09,
#   'key': 0.11,
#   'bjp': 0.09,
#   'win': 0.09,
#   'overal': 0.11,
#   'major': 0.08,
#   '1998': 0.09,
#   'elect': 0.04,
#   'modi': 0.01,
#   'promot': 0.11,
#   'gener': 0.07,
#   'secretari': 0.07,
#   'organis': 0.06,
#   'may': 0.11,
#   'year': 0.06}}

# %%
def score_sentence(tf_idf_matrix):
    sent_score={}
    for sent,tf_table in tf_idf_matrix.items():
        for word,value in tf_table.items():
            if sent not in sent_score.keys():
                sent_score[sent]=value
            else:
                sent_score[sent]+=value
    return sent_score

# %%
sent_score=score_sentence(tf_idf_matrix1)
sent_score
# Out:
# {'Narendra Damoda': 1.4300000000000004,
#  'He was the chie': 1.27,
#  'Modi is a membe': 1.29,
#  'He is also a me': 1.33,
#  'He is the first': 1.8800000000000003,
#  'Born and raised': 1.34,
#  'He was introduc': 1.31,
#  'Modi left home ': 1.4400000000000002,
#  'Modi has assert': 1.41,
#  'Upon his return': 1.25,
#  'During the stat': 1.3199999999999998,
#  'The RSS assigne': 1.4900000000000002,
#  'Modi was appoin': 1.3499999999999999,
#  'Modi was electe': 1.11,
#  'His administrat': 1.5900000000000003,
#  'A Supreme Court': 1.5299999999999996,
#  'His policies as': 1.6199999999999999,
#  'Modi led the BJ': 1.4300000000000004,
#  "Modi's administ": 1.6999999999999997,
#  'Modi has attemp': 1.6299999999999997,
#  'He began a high': 1.71,
#  "Under Modi's te": 1.4400000000000002,
#  'Following his p': 1.4399999999999997,
#  'Described as en': 1.550000000000001,
#  'Early life and ': 1.33,
#  'He was the thir': 1.7299999999999998,
#  "Modi's family b": 1.4400000000000006,
#  'He was falsely ': 1.67,
#  'As a child, Mod': 1.6100000000000005,
#  'Modi completed ': 1.58,
#  'Modi had an ear': 1.3599999999999999,
#  'Modi preferred ': 1.5499999999999998,
#  'When eight year': 1.5000000000000004,
#  'There, Modi met': 1.3800000000000003,
#  'While Modi was ': 1.2700000000000002,
#  'In a custom tra': 1.6000000000000003,
#  'Soon afterwards': 1.5500000000000003,
#  'In April 2014, ': 1.5300000000000005,
#  'Modi spent the ': 1.38,
#  'In interviews, ': 1.5200000000000002,
#  'Modi remained o': 1.4500000000000002,
#  'Vivekananda has': 1.34,
#  'In the early su': 1.6800000000000006,
#  'Modi then went ': 1.3599999999999999,
#  'Sometime in lat': 1.46,
#  'There, Modi liv': 1.41,
#  'In Ahmedabad, M': 1.46,
#  "Modi's first kn": 1.5200000000000005,
#  'But the Indira ': 1.4200000000000004,
#  'After the Indo-': 1.4200000000000004,
#  'Shortly before ': 1.2600000000000005,
#  'Many years late': 1.38,
#  'In 1978 Modi re': 1.29,
#  'Five years late': 1.3600000000000003,
#  'Early political': 1.52,
#  'During this per': 1.49,
#  'Shortly afterwa': 1.39,
#  'Modi was forced': 1.33,
#  'He became invol': 1.5400000000000003,
#  'Modi was also i': 1.5600000000000003,
#  'Among the peopl': 1.5000000000000004,
#  'In his travels ': 1.5799999999999998,
#  'Modi became an ': 1.4600000000000009,
#  'He returned to ': 1.0899999999999999,
#  'In 1987 Modi he': 1.4100000000000001,
#  'After L. K. Adv': 1.4100000000000008,
#  'Modi rose withi': 1.6000000000000005,
#  'However, he too': 1.5300000000000002,
#  'Modi returned t': 1.3900000000000003,
#  'In November of ': 1.3500000000000003,
#  'The following y': 1.3900000000000003,
#  'Modi, on the se': 1.5200000000000005,
#  'His strategy wa': 1.2800000000000002}

# %%
def average_score(sent_score):
    sum_sent=0
    for value in sent_score.values():
        sum_sent+=value
    avg_score=round(sum_sent/len(sent_score),2)
    return avg_score

# %%
def get_summary(sentences,sentence_score,threshold):
    summary=""
    for sent in sentences:
        if(sent[:15] in sentence_score) and sentence_score[sent[:15]]>threshold:
            summary=summary+" "+sent
    return summary

# %%
def lets_summarize(text):
    sentences=sent_tokenize(text)
    freq_matrix=frequency_matrix(text)
    tf_matrix1=tf_matrix(freq_matrix)
    doc_matrix=doc_frequency(freq_matrix)
    idf1_matrix=idf_matrix(freq_matrix,doc_matrix)
    tf_idf_matrix1=tf_idf_matrix(tf_matrix1,idf1_matrix)
    sent_score=score_sentence(tf_idf_matrix1)
    threshold=average_score(sent_score)
    summary=get_summary(sentences,sent_score,1.15*threshold)
    return summary

# %%
lets_summarize(text1)
# Out:
# " He is the first prime minister born after India's independence in 1947, the second non-Congress one to win two consecutive terms after Atal Bihari Vajpayee and the first from outside the Congress to win both terms with a majority in the Lok Sabha. Modi's administration has tried to raise foreign direct investment in the Indian economy and reduced spending on healthcare and social welfare programmes. He began a high-profile sanitation campaign, initiated a controversial demonetisation of high-denomination banknotes and weakened or abolished environmental and labour laws. He was the third of six children born to Damodardas Mulchand Modi (c.â€‰1915â€“1989) and Hiraben Modi (born c.â€‰1920). He was falsely accused by Mayawati that he added his caste to the Other Backward Class (OBC) list as a political tool. In the early summer of 1968, Modi reached the Belur Math but was turned away, after which Modi wandered through Calcutta, West Bengal and Assam, stopping in Siliguri and Guwahati."

# %%
sentences=sent_tokenize(text1)
threshold=average_score(sent_score)

# %%
see=get_summary(sentences,sent_score,1.15*threshold)

# %%
see
# Out:
# " He is the first prime minister born after India's independence in 1947, the second non-Congress one to win two consecutive terms after Atal Bihari Vajpayee and the first from outside the Congress to win both terms with a majority in the Lok Sabha. Modi's administration has tried to raise foreign direct investment in the Indian economy and reduced spending on healthcare and social welfare programmes. He began a high-profile sanitation campaign, initiated a controversial demonetisation of high-denomination banknotes and weakened or abolished environmental and labour laws. He was the third of six children born to Damodardas Mulchand Modi (c.â€‰1915â€“1989) and Hiraben Modi (born c.â€‰1920). He was falsely accused by Mayawati that he added his caste to the Other Backward Class (OBC) list as a political tool. In the early summer of 1968, Modi reached the Belur Math but was turned away, after which Modi wandered through Calcutta, West Bengal and Assam, stopping in Siliguri and Guwahati."
